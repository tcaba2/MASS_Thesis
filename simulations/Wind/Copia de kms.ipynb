# %%
import matplotlib.pyplot as plt
from pathlib import Path

import gammapy
import numpy as np
import astropy
import regions
import scipy

print("gammapy:", gammapy.__version__)
print("numpy:", np.__version__)
print("astropy", astropy.__version__)
print("regions", regions.__version__)
print("scipy", scipy.__version__)


from astropy.coordinates import SkyCoord
import astropy.units as u
from astropy.io import fits
from astropy.table import Table
from astropy.time import Time
from astropy.coordinates import SkyCoord, Angle

from regions import CircleSkyRegion

from gammapy.data import DataStore, GTI, Observation, EventList
from gammapy.datasets import (FluxPointsDataset, MapDataset, MapDatasetEventSampler, 
                              Datasets, SpectrumDataset, SpectrumDatasetOnOff)
from gammapy.maps import MapAxis, WcsGeom, Map
from gammapy.irf import load_irf_dict_from_file
from gammapy.makers import SafeMaskMaker, SpectrumDatasetMaker, ReflectedRegionsBackgroundMaker, MapDatasetMaker
from gammapy.modeling import Fit
from gammapy.modeling.models import (
    Model,
    Models,
    SkyModel,
    PowerLawSpectralModel,
    PowerLawNormSpectralModel,
    ExpCutoffPowerLawSpectralModel,
    PointSpatialModel,
    GaussianSpatialModel,
    TemplateSpatialModel,
    TemplateSpectralModel,
    FoVBackgroundModel,
)


import copy
import scipy.stats as stats

from gammapy.estimators import (
    FluxPoints, 
    FluxPointsEstimator, 
    TSMapEstimator
)

from regions import CircleSkyRegion
# Out:
# gammapy: 1.3
# numpy: 2.1.3
# astropy 6.1.6
# regions 0.10
# scipy 1.14.1

# %%
import warnings
from gammapy.utils.deprecation import GammapyDeprecationWarning
# 1. Hide the Gammapy “FixedPointingInfo will be required” notice
warnings.filterwarnings("ignore", category=GammapyDeprecationWarning)

# %%
BASE_PATH=Path(".")

# %%
def save_figure(filename):       #routine for saving figures
    path = BASE_PATH / filename      #saving paths
    path.parent.mkdir(parents=True, exist_ok=True)  #create a directory
    plt.savefig(path, dpi=300, bbox_inches='tight')     #dpi is the resolution
    plt.clf()                #clear
    plt.close()

# %%
import os
Nsim = 100              #definition of simulation number

## Creation of needed directories

Nsims=f"./{Nsim}sims"
try:
    # Create target Directory
    os.mkdir(Nsims)
except FileExistsError:
    print("Directory " , Nsims ,  " already exists")
    
events=f"./{Nsim}sims/events"
try:
    os.mkdir(events)
except FileExistsError:
    print("Directory " , events ,  " already exists")   
    
bestfit=f"./{Nsim}sims/best-fit"
try:
    os.mkdir(bestfit)
except FileExistsError:
    print("Directory " , bestfit ,  " already exists")  

spectra=f"./{Nsim}sims/spectra"
try:
    os.mkdir(spectra)
    print("Directory " , spectra ,  " Created ") 
except FileExistsError:
    print("Directory " , spectra ,  " already exists")
# Out:
# Directory  ./100sims/spectra  Created

# %%
####
# MAP GEOMETRY
####

ENERGY_AXIS = MapAxis.from_energy_bounds(
    "0.1 TeV", "100.0 TeV", nbin=10, per_decade=True       #IRF range
)
ENERGY_AXIS_TRUE = MapAxis.from_energy_bounds(
    "0.01 TeV", "350 TeV", nbin=20, per_decade=True, name="energy_true"    #larger range for E_true
)
MIGRA_AXIS = MapAxis.from_bounds(
    0.5, 2, nbin=150, node_type="edges", name="migra"
)

center = SkyCoord.from_name("NGC 1068").icrs

offset = 0.5 * u.deg

pointing_position = center.directional_offset_by(
    position_angle=0 * u.deg, separation=offset
)

WCS_GEOM = WcsGeom.create(
    skydir=pointing_position,
    width=(10, 10),         #REMEMBER: if you want to point off-axis 4°, you need a wider field     
    binsz=0.02,          #binsize simulation << PSF 
    frame="icrs",
    axes=[ENERGY_AXIS],
)

# %%
MainSource = "NGC1068"        #here insert all the information that I want in the filename
MainSourceAn = "NGC1068_Wind"               #name that I have to put in the analysis

# %%
filename = "/Users/tharacaba/Desktop/Tesis_2/gammapy-datasets/1.3/cta-prod5-zenodo-fitsonly-v0/fits/CTA-Performance-prod5-v0.1-North-40deg.FITS/Prod5-North-40deg-AverageAz-4LSTs09MSTs.180000s-v0.1.fits"  
irfs = load_irf_dict_from_file(filename)

# %%
#########
# Empty dataset creation with infromation from IRF
########
empty = MapDataset.create(
    WCS_GEOM, 
    energy_axis_true=ENERGY_AXIS_TRUE, 
    migra_axis=MIGRA_AXIS,
    name="my-dataset",
)


#####
# IRF definition, exposure definition, observation definition--> see previous notebook
#####

LIVETIME = 100 * u.hr                          #observation time with units
ext = int(LIVETIME.value)                         # exposure time as integer"
obs_id="0001"                                     # obs_id could be everything


observation = Observation.create(
    obs_id=obs_id, pointing=pointing_position, livetime=LIVETIME, irfs=irfs 
) 


## which maps to make
maker = MapDatasetMaker(selection=["exposure", "background", "psf", "edisp"])    #with Edisp
#maker = MapDatasetMaker(selection=["exposure", "psf", "background"])          #without the Edisp


dataset = maker.run(empty, observation)

dataset.write(f"dataset_{MainSource}_{ext}hr.fits", overwrite=True)
print(dataset)
# Out:
# MapDataset
# ----------
#
#   Name                            : my-dataset
#
#   Total counts                    : 0
#   Total background counts         : 10823072.70
#   Total excess counts             : -10823072.70
#
#   Predicted counts                : 10823072.70
#   Predicted background counts     : 10823072.70
#   Predicted excess counts         : nan
#
#   Exposure min                    : 5.62e+00 m2 s
#   Exposure max                    : 6.00e+11 m2 s
#
#   Number of total bins            : 7500000
#   Number of fit bins              : 7500000
#
#   Fit statistic type              : cash
#   Fit statistic value (-2 log(L)) : nan
#
#   Number of models                : 0
#   Number of parameters            : 0
#   Number of free parameters       : 0

# %%
from astropy.io import ascii

# Source
point_model = PointSpatialModel(
    lon_0="40.669 deg", 
    lat_0="-0.013 deg", 
    frame='icrs'
)

# Template spectral model. Defined by custom tabular values from Inoue+ 2022
data = ascii.read("Inoue_2022_wind.dat")

data['Frequency[Hz]'] = 10**data['logFrequency[Hz]'] 
data['flux[ergcm^-2s^-1]'] = 10**data['logflux[ergcm^-2s^-1]']

energy_bounds = [0.1, 100] * u.TeV
energy = data['Frequency[Hz]'] * u.Hz
values = data['flux[ergcm^-2s^-1]'] *u.erg / (u.cm **2.0 * u.s)

energy_MeV = energy.to(u.MeV, equivalencies=u.spectral())

values = values.to(u.MeV / (u.cm ** 2.0 * u.s))
values_MeV = values / energy_MeV**2  # divide by energy to get dN/dE

spectral_model = TemplateSpectralModel(energy=energy_MeV, values=values_MeV)


# Background
bkg_model = FoVBackgroundModel(dataset_name="my-dataset")



sky_model = SkyModel(
                    spectral_model=spectral_model,
                    spatial_model=point_model,
 #                   temporal_model=expdecay_model,
                    name=MainSourceAn,
                    )

# Define the whole model
models = Models([sky_model, bkg_model])


models[0].spatial_model.parameters['lon_0'].frozen=True       #Spatial coordinate freezed
models[0].spatial_model.parameters['lat_0'].frozen=True

print(models) 

#print(models.to_yaml())
# save it to disk
file_model = "./NGC1068_Nsim_Wind.yaml"
models.write(file_model, overwrite=True)

spectral_model.plot(energy_bounds, sed_type="e2dnde")
plt.grid(which="both")
# Out:
# Models
#
# Component 0: SkyModel
#
#   Name                      : NGC1068_Wind
#   Datasets names            : None
#   Spectral model type       : TemplateSpectralModel
#   Spatial  model type       : PointSpatialModel
#   Temporal model type       :
#   Parameters:
#     lon_0                 (frozen):     40.669       deg
#     lat_0                 (frozen):     -0.013       deg
#
# Component 1: FoVBackgroundModel
#
#   Name                      : my-dataset-bkg
#   Datasets names            : ['my-dataset']
#   Spectral model type       : PowerLawNormSpectralModel
#   Parameters:
#     norm                          :      1.000   +/-    0.00
#     tilt                  (frozen):      0.000
#     reference             (frozen):      1.000       TeV

# %%
from gammapy.data import observatory_locations

exp = [100]     

for j in exp:         #loop on exposure times
    ext = int(j)      # to facilitate the references in the loops
    dataset = MapDataset.read(f'dataset_{MainSource}_{ext}hr.fits', name="my-dataset") #read the one that we created
    dataset.models = models     
    dataset_original = models.copy()         #this will be useful for the final plot
    for i in np.arange(Nsim):                 # we simulate N times
        observation = Observation.create(
        obs_id=i, pointing=pointing_position, livetime=j*u.hr, irfs=irfs, tstart = 30 * u.min, reference_time = Time("2026-05-28T00:00:00", format="isot", scale="utc"),
        location = observatory_locations["cta_north"]
        )
        
        sampler = MapDatasetEventSampler(random_state=i)
        events = sampler.run(dataset, observation)

        observation.events = events
        observation.write(f"./{Nsim}sims/events/{MainSource}_{ext}hr_events_{i}.fits", include_irfs=False, overwrite=True)
# Out:
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.
# The meta information will be empty here.

# %%
import glob, os, itertools
input_filenames = []
input_filenames.append(glob.glob(os.path.join("/Users/tharacaba/Desktop/Tesis_2/MASS_Thesis/simulations/Wind/100sims/events/", '*.fits')))
input_filenames = tuple(itertools.chain.from_iterable(input_filenames))

datastore = DataStore.from_events_files(np.sort(input_filenames), irfs_paths="/Users/tharacaba/Desktop/Tesis_2/gammapy-datasets/1.3/cta-prod5-zenodo-fitsonly-v0/fits/CTA-Performance-prod5-v0.1-North-40deg.FITS/Prod5-North-40deg-AverageAz-4LSTs09MSTs.180000s-v0.1.fits")
datastore.hdu_table.write("hdu-index.fits.gz", overwrite=True)
datastore.obs_table.write("obs-index.fits.gz", overwrite=True)

# %%
from gammapy.maps import MapAxis, RegionGeom
# let's load the previously created Observation index files:

center = SkyCoord.from_name("NGC 1068").icrs

offset = 0.5 * u.deg

pointing_position = center.directional_offset_by(
    position_angle=0 * u.deg, separation=offset
)

observations = datastore.get_observations(obs_id=list(datastore.obs_table['OBS_ID']))

# we consider a square map of size 2.0 deg, spatially binned with bins of 0.02 deg;
# we define the ON region, assuming a circle of 0.2 deg of radius, for the source;
width = 2.0  #deg
binsz = 0.02 #deg
radius= 0.11  #deg

# let's define an exclusion region, in order to better estimate the bkg:
target_position = SkyCoord(40.669 * u.deg, -0.013 * u.deg, frame="icrs", unit="deg")
on_region_radius = Angle(radius * u.deg)
on_region = CircleSkyRegion(center=target_position, radius=on_region_radius)

npix = int(width/binsz)

exclusion_region = CircleSkyRegion(
    center=target_position,
    radius=radius * u.deg,
)

geom_excl = WcsGeom.create(
    npix=(npix, npix), binsz=binsz, skydir=target_position.galactic, proj="TAN", frame="galactic"
    #npix=(npix, npix), binsz=binsz, skydir=w1.galactic, proj="TAN", frame="galactic"
)

exclusion_mask = ~geom_excl.region_mask([exclusion_region])

# # Create the reconstruced energy range:
# e_min, e_max = 0.1 * u.TeV, 100 * u.TeV

energy_bounds=[10 * u.GeV, 10 * u.TeV]

energy_axis = MapAxis.from_energy_bounds(
    energy_bounds[0], energy_bounds[1], nbin=10, per_decade=True, unit="TeV", name="energy"
)

# Reduced IRFs are defined in true energy (i.e. not measured energy).
energy_axis_true = MapAxis.from_energy_bounds(
    energy_bounds[0] * 0.8,
        energy_bounds[1] * 1.2, nbin=13, per_decade=True, unit="TeV", name="energy_true"
)

# geometry defining the ON region and SpectrumDataset based on it
geom = RegionGeom.create(region=on_region, axes=[energy_axis])

dataset_empty = SpectrumDataset.create(geom=geom, energy_axis_true=energy_axis_true)

dataset_maker = SpectrumDatasetMaker(
    containment_correction=True, selection=["counts", "exposure", "edisp"]
)

# tell the background maker to determine the reflected regions, excluding the source region:
maker_fov = ReflectedRegionsBackgroundMaker(exclusion_mask=exclusion_mask)

# let's impone a safe range for the analysis: we consider only events at a distance from the pointing direction < 1 deg.
safe_mask_maker = SafeMaskMaker(
        methods=["aeff-max"], aeff_percent=10, position=pointing_position
    )

# create a counts map for visualisation later...
counts = Map.create(skydir=target_position, width=3)

# let's create the dataset for each observation and stack them all:
datasets = Datasets()

# let's loop over observations
for observation in observations:
    # generate a dataset object
    dataset = dataset_maker.run(
        dataset_empty.copy(name=str(observation.obs_id)), observation
    )
    # fill the dataset with the events of the observation
    counts.fill_events(observation.events)

    # calculate the bkg
    dataset_on_off = maker_fov.run(dataset, observation)
    # set a safe range for the analysis
    dataset_on_off = safe_mask_maker.run(dataset_on_off, observation)

    datasets.append(dataset_on_off)

# %%
from gammapy.stats import WStatCountsStatistic

LIVETIME = 100 * u.hr

# Define alpha value used for all datasets
alpha = 0.083

# Container for significances
sig_distrib = []

# Loop through all datasets
for dataset in datasets:
    bin_index = dataset.mask_safe.quantity

    on_events = dataset.counts.data[bin_index].sum()
    off_events = dataset.counts_off.data[bin_index].sum()

    # Calculate significance using WStat
    stat = WStatCountsStatistic(on_events, off_events, alpha)
    significance = stat.sqrt_ts

    sig_distrib.append(significance)

# Convert to numpy array
sig_distrib = np.array(sig_distrib)

# Calculate mean and std
mean = sig_distrib.mean()
std = sig_distrib.std()

# Plot histogram
plt.figure()
plt.hist(sig_distrib, bins=10, edgecolor="black")
plt.axvline(mean, color="red", label="Mean")

# ±2σ lines
plt.axvline(mean + 2 * std, color="red", linestyle="--", label="±2σ")
plt.axvline(mean - 2 * std, color="red", linestyle="--")

plt.xlabel(r"Significance (in $\sigma$)")
plt.ylabel("Counts")
plt.title(f"Distribution of significance of NGC 1068 for Wind model, livetime = {LIVETIME}, northern array, 100 simulations")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# Print results
print(f"Significance : {mean:.2f} +/- {std:.2f}")
# Out:
# Significance : 15.70 +/- 0.92

# %%
spectral_model = PowerLawSpectralModel(
    amplitude = 5.76e-14  * u.Unit("cm-2 s-1 TeV-1"),
    index = 2.3,
    reference = 1 * u.TeV,
)

sky_model = SkyModel(
                    spectral_model=spectral_model,
                    spatial_model=point_model,
 #                   temporal_model=expdecay_model,
                    name=MainSourceAn,
                    )

# Define the whole model
models = Models([sky_model, bkg_model])


models[0].spatial_model.parameters['lon_0'].frozen=True       #Spatial coordinate freezed
models[0].spatial_model.parameters['lat_0'].frozen=True

file_model = "./NGC1068_PL.yaml"
models.write(file_model, overwrite=True)

# %%
# %%time

exp = [50]  
Nsim = 100 
dataset_original = Models.read("/Users/tharacaba/Desktop/Tesis_2/MASS_Thesis/simulations/Fermi/Experiment/Fermi_NGC_1068.yaml") 

e_min, e_max, e_bins = 0.1, 100.0, 10
e_edges = np.logspace(np.log10(e_min), np.log10(e_max), e_bins) * u.TeV

for j in np.array([exp]):            # for every exposure time
    ext = int(j)
    print(f"Exposure time: {ext} hr")
    for i in np.arange(Nsim):    #for each of the N simulations
        dataset = MapDataset.read(f'dataset_{MainSource}_{ext}hr.fits')
        dataset.models = models
        print(f"  Read events: {i}")
        events = EventList.read(f"./{Nsim}sims/events/{MainSource}_{ext}hr_events_{i}.fits")
        counts = Map.from_geom(WCS_GEOM)
        counts.fill_events(events)
        dataset.counts = counts

        print(f"    Fit data ...")
        fit = Fit(optimize_opts={"print_level": 1})
        result = fit.run([dataset])
        dataset.models.write(f"./{Nsim}sims/best-fit/{MainSource}_{ext}hr_best-fit_{i}.yaml", overwrite=True)

        print(f"    Calculate flux points ...")
        fpe = FluxPointsEstimator(energy_edges=e_edges, source=MainSourceAn)
        flux_points = fpe.run(datasets=dataset)
        flux_points.is_ul = flux_points.ts < 9
        flux_points.write(f"./{Nsim}sims/spectra/{MainSource}_{ext}hr_spectrum_{i}.fits", overwrite=True)

        print(f"    Plot spectra ...")
        ax = dataset_original[0].spectral_model.plot(
            energy_bounds=(0.1, 400) * u.TeV, 
            label="Sim. model",
            sed_type="e2dnde",
            color='black'
        )

        px = {"color": "red", "marker":"o"}
        mx = {"color": "blue"}

        flux_points_dataset = FluxPointsDataset(data=flux_points, models=dataset.models[0])
        flux_points_dataset.plot_spectrum(ax=ax, kwargs_fp=px, kwargs_model=mx)
        ax.legend()
        #ax.set_ylim(2e-14,1e-12)
        filename = f"./{Nsim}sims/plots_{ext}hr/{MainSource}_spectrum_{i}.png"
        save_figure(filename)
# Out:
# <timed exec>:9: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
# Exposure time: 50 hr
#   Read events: 0
#     Fit data ...
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.00134337 is smaller than machine limit 0.405113 while 0.0002 was requested
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 1
#     Fit data ...
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.00188326 is smaller than machine limit 0.403789 while 0.0002 was requested
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 2
#     Fit data ...
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.000412793 is smaller than machine limit 0.40418 while 0.0002 was requested
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 3
#     Fit data ...
# W VariableMetricBuilder No improvement in line search
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 4
#     Fit data ...
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.00273936 is smaller than machine limit 0.404746 while 0.0002 was requested
# W VariableMetricBuilder No convergence; Edm 0.00273936 is above tolerance 0.002
# W DavidonErrorUpdator delgam < 0 : first derivatives increasing along search line (details in info log)
# W VariableMetricBuilder Matrix not pos.def, gdel = 0.0122383 > 0
# W MnPosDef non-positive diagonal element in covariance matrix[ 0 ] = -0.0569165
# W MnPosDef non-positive diagonal element in covariance matrix[ 1 ] = -6.6442
# W MnPosDef Added to diagonal of Error matrix a value 7.1442
# W VariableMetricBuilder gdel = -4.2007
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Iterations finish without convergence; Edm 14.1316 Requested 0.0002
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 5
#     Fit data ...
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.0291369 is smaller than machine limit 0.404021 while 0.0002 was requested
# W VariableMetricBuilder No convergence; Edm 0.0291369 is above tolerance 0.002
# W DavidonErrorUpdator delgam < 0 : first derivatives increasing along search line (details in info log)
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Edm is limited by Machine accuracy - return current minimum
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 6
#     Fit data ...
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.000935427 is smaller than machine limit 0.404555 while 0.0002 was requested
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 7
#     Fit data ...
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.00448077 is smaller than machine limit 0.40426 while 0.0002 was requested
# W VariableMetricBuilder No convergence; Edm 0.00448077 is above tolerance 0.002
# W DavidonErrorUpdator delgam < 0 : first derivatives increasing along search line (details in info log)
# W VariableMetricBuilder Matrix not pos.def, gdel = 0.00260522 > 0
# W MnPosDef non-positive diagonal element in covariance matrix[ 0 ] = -0.00254792
# W MnPosDef Added to diagonal of Error matrix a value 0.502548
# W VariableMetricBuilder gdel = -1.77235
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Edm is limited by Machine accuracy - return current minimum
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 8
#     Fit data ...
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.000828152 is smaller than machine limit 0.404623 while 0.0002 was requested
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 9
#     Fit data ...
# W DavidonErrorUpdator delgam < 0 : first derivatives increasing along search line (details in info log)
# W VariableMetricBuilder Matrix not pos.def, gdel = 0.000925159 > 0
# W MnPosDef non-positive diagonal element in covariance matrix[ 1 ] = -0.579781
# W MnPosDef Added to diagonal of Error matrix a value 1.07978
# W VariableMetricBuilder gdel = -963.692
# W DavidonErrorUpdator delgam < 0 : first derivatives increasing along search line (details in info log)
# W VariableMetricBuilder Matrix not pos.def, gdel = 0.000413746 > 0
# W MnPosDef non-positive diagonal element in covariance matrix[ 0 ] = -0.00105916
# W MnPosDef Added to diagonal of Error matrix a value 0.501059
# W VariableMetricBuilder gdel = -0.209988
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Edm is limited by Machine accuracy - return current minimum
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.000688361 is smaller than machine limit 0.403856 while 0.0002 was requested
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 10
#     Fit data ...
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.000483054 is smaller than machine limit 0.404404 while 0.0002 was requested
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 11
#     Fit data ...
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Edm is limited by Machine accuracy - return current minimum
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.00392564 is smaller than machine limit 0.405229 while 0.0002 was requested
# W VariableMetricBuilder No convergence; Edm 0.00392564 is above tolerance 0.002
# W DavidonErrorUpdator delgam < 0 : first derivatives increasing along search line (details in info log)
# W VariableMetricBuilder Matrix not pos.def, gdel = 0.00230435 > 0
# W MnPosDef non-positive diagonal element in covariance matrix[ 0 ] = -0.00106566
# W MnPosDef non-positive diagonal element in covariance matrix[ 2 ] = -4.50875e-06
# W MnPosDef Added to diagonal of Error matrix a value 0.501066
# W VariableMetricBuilder gdel = -0.558629
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Iterations finish without convergence; Edm 0.923309 Requested 0.0002
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 12
#     Fit data ...
# W DavidonErrorUpdator delgam < 0 : first derivatives increasing along search line (details in info log)
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.000472708 is smaller than machine limit 0.403796 while 0.0002 was requested
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 13
#     Fit data ...
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.00089534 is smaller than machine limit 0.405803 while 0.0002 was requested
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 14
#     Fit data ...
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.00221716 is smaller than machine limit 0.403499 while 0.0002 was requested
# W VariableMetricBuilder No convergence; Edm 0.00221716 is above tolerance 0.002
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 15
#     Fit data ...
# W VariableMetricBuilder No improvement in line search
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 16
#     Fit data ...
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.00419229 is smaller than machine limit 0.404349 while 0.0002 was requested
# W VariableMetricBuilder No convergence; Edm 0.00419229 is above tolerance 0.002
# W DavidonErrorUpdator delgam < 0 : first derivatives increasing along search line (details in info log)
# W VariableMetricBuilder Matrix not pos.def, gdel = 0.000589564 > 0
# W MnPosDef non-positive diagonal element in covariance matrix[ 0 ] = -0.000302805
# W MnPosDef Added to diagonal of Error matrix a value 0.500303
# W VariableMetricBuilder gdel = -0.327791
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Edm is limited by Machine accuracy - return current minimum
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 17
#     Fit data ...
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.000382038 is smaller than machine limit 0.404229 while 0.0002 was requested
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 18
#     Fit data ...
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Edm is limited by Machine accuracy - return current minimum
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.00190664 is smaller than machine limit 0.404949 while 0.0002 was requested
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 19
#     Fit data ...
# W VariableMetricBuilder No improvement in line search
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 20
#     Fit data ...
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.000295907 is smaller than machine limit 0.404627 while 0.0002 was requested
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 21
#     Fit data ...
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.00555188 is smaller than machine limit 0.403627 while 0.0002 was requested
# W VariableMetricBuilder No convergence; Edm 0.00555188 is above tolerance 0.002
# W DavidonErrorUpdator delgam < 0 : first derivatives increasing along search line (details in info log)
# W VariableMetricBuilder Matrix not pos.def, gdel = 0.000394292 > 0
# W MnPosDef Matrix forced pos-def by adding to diagonal 1.76798
# W VariableMetricBuilder gdel = -0.000518401
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 22
#     Fit data ...
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.000493238 is smaller than machine limit 0.40442 while 0.0002 was requested
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 23
#     Fit data ...
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.00299698 is smaller than machine limit 0.404419 while 0.0002 was requested
# W VariableMetricBuilder No convergence; Edm 0.00299698 is above tolerance 0.002
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 24
#     Fit data ...
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.000710561 is smaller than machine limit 0.404381 while 0.0002 was requested
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 25
#     Fit data ...
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.00116384 is smaller than machine limit 0.404895 while 0.0002 was requested
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 26
#     Fit data ...
# W DavidonErrorUpdator delgam < 0 : first derivatives increasing along search line (details in info log)
# W VariableMetricBuilder Matrix not pos.def, gdel = 0.000285959 > 0
# W MnPosDef non-positive diagonal element in covariance matrix[ 0 ] = -0.000165347
# W MnPosDef Added to diagonal of Error matrix a value 0.500165
# W VariableMetricBuilder gdel = -11.6127
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Edm is limited by Machine accuracy - return current minimum
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.000240817 is smaller than machine limit 0.404807 while 0.0002 was requested
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 27
#     Fit data ...
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.00325611 is smaller than machine limit 0.40491 while 0.0002 was requested
# W VariableMetricBuilder No convergence; Edm 0.00325611 is above tolerance 0.002
# W DavidonErrorUpdator delgam < 0 : first derivatives increasing along search line (details in info log)
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Edm is limited by Machine accuracy - return current minimum
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 28
#     Fit data ...
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.000376582 is smaller than machine limit 0.404442 while 0.0002 was requested
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 29
#     Fit data ...
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.000565053 is smaller than machine limit 0.405177 while 0.0002 was requested
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 30
#     Fit data ...
# W VariableMetricBuilder No improvement in line search
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 31
#     Fit data ...
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.000405657 is smaller than machine limit 0.403816 while 0.0002 was requested
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 32
#     Fit data ...
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.00429588 is smaller than machine limit 0.404353 while 0.0002 was requested
# W VariableMetricBuilder No convergence; Edm 0.00429588 is above tolerance 0.002
# W DavidonErrorUpdator delgam < 0 : first derivatives increasing along search line (details in info log)
# W VariableMetricBuilder Matrix not pos.def, gdel = 0.000942969 > 0
# W MnPosDef non-positive diagonal element in covariance matrix[ 0 ] = -0.00122199
# W MnPosDef Added to diagonal of Error matrix a value 0.501222
# W VariableMetricBuilder gdel = -0.407799
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Iterations finish without convergence; Edm 0.674815 Requested 0.0002
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.000335377 is smaller than machine limit 0.404353 while 0.0002 was requested
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 33
#     Fit data ...
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Edm is limited by Machine accuracy - return current minimum
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.00341125 is smaller than machine limit 0.404917 while 0.0002 was requested
# W VariableMetricBuilder No convergence; Edm 0.00341125 is above tolerance 0.002
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 34
#     Fit data ...
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.00183598 is smaller than machine limit 0.404325 while 0.0002 was requested
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 35
#     Fit data ...
# W DavidonErrorUpdator delgam < 0 : first derivatives increasing along search line (details in info log)
# W DavidonErrorUpdator delgam < 0 : first derivatives increasing along search line (details in info log)
# W DavidonErrorUpdator gvg <= 0 : cannot update - return same matrix
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.000337486 is smaller than machine limit 0.404755 while 0.0002 was requested
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 36
#     Fit data ...
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Edm is limited by Machine accuracy - return current minimum
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 37
#     Fit data ...
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.00494008 is smaller than machine limit 0.405203 while 0.0002 was requested
# W VariableMetricBuilder No convergence; Edm 0.00494008 is above tolerance 0.002
# W DavidonErrorUpdator delgam < 0 : first derivatives increasing along search line (details in info log)
# W VariableMetricBuilder Matrix not pos.def, gdel = 0.000409022 > 0
# W MnPosDef Matrix forced pos-def by adding to diagonal 1.30908
# W VariableMetricBuilder gdel = -0.000305975
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 38
#     Fit data ...
# W DavidonErrorUpdator delgam < 0 : first derivatives increasing along search line (details in info log)
# W VariableMetricBuilder Matrix not pos.def, gdel = 8.30443e-05 > 0
# W MnPosDef non-positive diagonal element in covariance matrix[ 0 ] = -6.76785e-05
# W MnPosDef non-positive diagonal element in covariance matrix[ 1 ] = -0.0937347
# W MnPosDef Added to diagonal of Error matrix a value 0.593735
# W VariableMetricBuilder gdel = -188.439
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Edm is limited by Machine accuracy - return current minimum
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.000613544 is smaller than machine limit 0.405997 while 0.0002 was requested
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 39
#     Fit data ...
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.000529031 is smaller than machine limit 0.405424 while 0.0002 was requested
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 40
#     Fit data ...
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Edm is limited by Machine accuracy - return current minimum
# W VariableMetricBuilder No convergence; Edm 0.00249428 is above tolerance 0.002
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 41
#     Fit data ...
# W DavidonErrorUpdator delgam < 0 : first derivatives increasing along search line (details in info log)
# W VariableMetricBuilder Matrix not pos.def, gdel = 0.0891947 > 0
# W MnPosDef non-positive diagonal element in covariance matrix[ 0 ] = -0.0649992
# W MnPosDef non-positive diagonal element in covariance matrix[ 1 ] = -0.858774
# W MnPosDef Added to diagonal of Error matrix a value 1.35877
# W VariableMetricBuilder gdel = -1.90038
# W DavidonErrorUpdator delgam < 0 : first derivatives increasing along search line (details in info log)
# W VariableMetricBuilder Matrix not pos.def, gdel = 0.00384479 > 0
# W MnPosDef non-positive diagonal element in covariance matrix[ 0 ] = -0.00432685
# W MnPosDef Added to diagonal of Error matrix a value 0.504327
# W VariableMetricBuilder gdel = -0.545477
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Iterations finish without convergence; Edm 0.878768 Requested 0.0002
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 42
#     Fit data ...
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.00190246 is smaller than machine limit 0.405086 while 0.0002 was requested
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 43
#     Fit data ...
# W VariableMetricBuilder No improvement in line search
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 44
#     Fit data ...
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.000219476 is smaller than machine limit 0.403952 while 0.0002 was requested
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 45
#     Fit data ...
# W DavidonErrorUpdator delgam < 0 : first derivatives increasing along search line (details in info log)
# W VariableMetricBuilder Matrix not pos.def, gdel = 1.40819e-05 > 0
# W MnPosDef non-positive diagonal element in covariance matrix[ 0 ] = -0.000291007
# W MnPosDef Added to diagonal of Error matrix a value 0.500291
# W VariableMetricBuilder gdel = -0.643021
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Edm is limited by Machine accuracy - return current minimum
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.000641786 is smaller than machine limit 0.403682 while 0.0002 was requested
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 46
#     Fit data ...
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Edm is limited by Machine accuracy - return current minimum
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.000371327 is smaller than machine limit 0.404594 while 0.0002 was requested
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 47
#     Fit data ...
# W MnPosDef Matrix forced pos-def by adding to diagonal 0.0176238
# W DavidonErrorUpdator delgam < 0 : first derivatives increasing along search line (details in info log)
# W VariableMetricBuilder Matrix not pos.def, gdel = 0.0276033 > 0
# W MnPosDef non-positive diagonal element in covariance matrix[ 0 ] = -0.00413393
# W MnPosDef non-positive diagonal element in covariance matrix[ 1 ] = -1.88988
# W MnPosDef Added to diagonal of Error matrix a value 2.38988
# W VariableMetricBuilder gdel = -5.78767
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Iterations finish without convergence; Edm 2.58138 Requested 0.0002
# W VariableMetricBuilder FunctionMinimum is invalid after second try
# W MnPosDef Matrix forced pos-def by adding to diagonal 0.0498775
# W DavidonErrorUpdator delgam < 0 : first derivatives increasing along search line (details in info log)
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Edm is limited by Machine accuracy - return current minimum
# W MnPosDef Matrix forced pos-def by adding to diagonal 0.0530486
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.000593308 is smaller than machine limit 0.404664 while 0.0002 was requested
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 48
#     Fit data ...
# W VariableMetricBuilder No improvement in line search
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 49
#     Fit data ...
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.00711159 is smaller than machine limit 0.40487 while 0.0002 was requested
# W VariableMetricBuilder No convergence; Edm 0.00711159 is above tolerance 0.002
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 50
#     Fit data ...
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.000256383 is smaller than machine limit 0.404881 while 0.0002 was requested
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 51
#     Fit data ...
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.00308333 is smaller than machine limit 0.405065 while 0.0002 was requested
# W VariableMetricBuilder No convergence; Edm 0.00308333 is above tolerance 0.002
# W DavidonErrorUpdator delgam < 0 : first derivatives increasing along search line (details in info log)
# W VariableMetricBuilder Matrix not pos.def, gdel = 0.000669105 > 0
# W MnPosDef Matrix forced pos-def by adding to diagonal 0.545554
# W VariableMetricBuilder gdel = -1.71905e-05
# W DavidonErrorUpdator delgam < 0 : first derivatives increasing along search line (details in info log)
# W DavidonErrorUpdator gvg <= 0 : cannot update - return same matrix
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 52
#     Fit data ...
# W DavidonErrorUpdator delgam < 0 : first derivatives increasing along search line (details in info log)
# W VariableMetricBuilder Matrix not pos.def, gdel = 0.00543301 > 0
# W MnPosDef non-positive diagonal element in covariance matrix[ 0 ] = -0.0232444
# W MnPosDef non-positive diagonal element in covariance matrix[ 1 ] = -0.358529
# W MnPosDef Added to diagonal of Error matrix a value 0.858529
# W VariableMetricBuilder gdel = -15.7872
# W DavidonErrorUpdator delgam < 0 : first derivatives increasing along search line (details in info log)
# W VariableMetricBuilder Matrix not pos.def, gdel = 4.55726e-05 > 0
# W MnPosDef Matrix forced pos-def by adding to diagonal 0.428356
# W VariableMetricBuilder gdel = -0.000128316
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 53
#     Fit data ...
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.0177929 is smaller than machine limit 0.404765 while 0.0002 was requested
# W VariableMetricBuilder No convergence; Edm 0.0177929 is above tolerance 0.002
# W DavidonErrorUpdator delgam < 0 : first derivatives increasing along search line (details in info log)
# W VariableMetricBuilder Matrix not pos.def, gdel = 0.00593401 > 0
# W MnPosDef non-positive diagonal element in covariance matrix[ 0 ] = -0.00184418
# W MnPosDef Added to diagonal of Error matrix a value 0.501844
# W VariableMetricBuilder gdel = -25.4992
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Iterations finish without convergence; Edm 2.16822 Requested 0.0002
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 54
#     Fit data ...
# W VariableMetricBuilder No improvement in line search
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 55
#     Fit data ...
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Edm is limited by Machine accuracy - return current minimum
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 56
#     Fit data ...
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.000288719 is smaller than machine limit 0.40369 while 0.0002 was requested
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 57
#     Fit data ...
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.00096031 is smaller than machine limit 0.404506 while 0.0002 was requested
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 58
#     Fit data ...
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.00111456 is smaller than machine limit 0.404269 while 0.0002 was requested
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 59
#     Fit data ...
# W VariableMetricBuilder No improvement in line search
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 60
#     Fit data ...
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Edm is limited by Machine accuracy - return current minimum
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.00703666 is smaller than machine limit 0.405205 while 0.0002 was requested
# W VariableMetricBuilder No convergence; Edm 0.00703666 is above tolerance 0.002
# W DavidonErrorUpdator delgam < 0 : first derivatives increasing along search line (details in info log)
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Edm is limited by Machine accuracy - return current minimum
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.000533038 is smaller than machine limit 0.405205 while 0.0002 was requested
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 61
#     Fit data ...
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.00250056 is smaller than machine limit 0.403796 while 0.0002 was requested
# W VariableMetricBuilder No convergence; Edm 0.00250056 is above tolerance 0.002
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 62
#     Fit data ...
# W DavidonErrorUpdator delgam < 0 : first derivatives increasing along search line (details in info log)
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.00490583 is smaller than machine limit 0.404811 while 0.0002 was requested
# W VariableMetricBuilder No convergence; Edm 0.00490583 is above tolerance 0.002
# W DavidonErrorUpdator delgam < 0 : first derivatives increasing along search line (details in info log)
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Edm is limited by Machine accuracy - return current minimum
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 63
#     Fit data ...
# W DavidonErrorUpdator delgam < 0 : first derivatives increasing along search line (details in info log)
# W VariableMetricBuilder No improvement in line search
# W MnPosDef Matrix forced pos-def by adding to diagonal 0.0171323
# W DavidonErrorUpdator delgam < 0 : first derivatives increasing along search line (details in info log)
# W VariableMetricBuilder Matrix not pos.def, gdel = 0.00541719 > 0
# W MnPosDef non-positive diagonal element in covariance matrix[ 0 ] = -0.00125909
# W MnPosDef Added to diagonal of Error matrix a value 0.501259
# W VariableMetricBuilder gdel = -1.4538
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Iterations finish without convergence; Edm 3.33043 Requested 0.0002
# W VariableMetricBuilder FunctionMinimum is invalid after second try
# W MnPosDef Matrix forced pos-def by adding to diagonal 0.0504209
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Edm is limited by Machine accuracy - return current minimum
# W MnPosDef Matrix forced pos-def by adding to diagonal 0.0487859
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.00107681 is smaller than machine limit 0.404439 while 0.0002 was requested
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 64
#     Fit data ...
# W DavidonErrorUpdator delgam < 0 : first derivatives increasing along search line (details in info log)
# W VariableMetricBuilder Matrix not pos.def., try to make pos.def.
# W MnPosDef non-positive diagonal element in covariance matrix[ 0 ] = -9.26804e-05
# W MnPosDef Added to diagonal of Error matrix a value 0.500093
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Iterations finish without convergence; Edm 3.28845 Requested 0.0002
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.00200172 is smaller than machine limit 0.404482 while 0.0002 was requested
# W VariableMetricBuilder No convergence; Edm 0.00200172 is above tolerance 0.002
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 65
#     Fit data ...
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.000471626 is smaller than machine limit 0.405644 while 0.0002 was requested
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 66
#     Fit data ...
# W VariableMetricBuilder No improvement in line search
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 67
#     Fit data ...
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.00154317 is smaller than machine limit 0.404732 while 0.0002 was requested
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 68
#     Fit data ...
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Edm is limited by Machine accuracy - return current minimum
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.000423594 is smaller than machine limit 0.403251 while 0.0002 was requested
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 69
#     Fit data ...
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.00079489 is smaller than machine limit 0.404693 while 0.0002 was requested
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 70
#     Fit data ...
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Edm is limited by Machine accuracy - return current minimum
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 71
#     Fit data ...
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Edm is limited by Machine accuracy - return current minimum
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.00233143 is smaller than machine limit 0.403721 while 0.0002 was requested
# W VariableMetricBuilder No convergence; Edm 0.00233143 is above tolerance 0.002
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 72
#     Fit data ...
# W VariableMetricBuilder No improvement in line search
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 73
#     Fit data ...
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.000841711 is smaller than machine limit 0.403821 while 0.0002 was requested
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 74
#     Fit data ...
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Edm is limited by Machine accuracy - return current minimum
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.000735503 is smaller than machine limit 0.404411 while 0.0002 was requested
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 75
#     Fit data ...
# W VariableMetricBuilder No improvement in line search
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 76
#     Fit data ...
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Edm is limited by Machine accuracy - return current minimum
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 77
#     Fit data ...
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.000875698 is smaller than machine limit 0.405358 while 0.0002 was requested
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 78
#     Fit data ...
# W DavidonErrorUpdator delgam < 0 : first derivatives increasing along search line (details in info log)
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.000362742 is smaller than machine limit 0.405207 while 0.0002 was requested
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 79
#     Fit data ...
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.000478057 is smaller than machine limit 0.404502 while 0.0002 was requested
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 80
#     Fit data ...
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.000263368 is smaller than machine limit 0.403657 while 0.0002 was requested
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 81
#     Fit data ...
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.000681268 is smaller than machine limit 0.404374 while 0.0002 was requested
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 82
#     Fit data ...
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.00072936 is smaller than machine limit 0.404526 while 0.0002 was requested
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 83
#     Fit data ...
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.000229237 is smaller than machine limit 0.404384 while 0.0002 was requested
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 84
#     Fit data ...
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.00220353 is smaller than machine limit 0.40398 while 0.0002 was requested
# W VariableMetricBuilder No convergence; Edm 0.00220353 is above tolerance 0.002
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 85
#     Fit data ...
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Edm is limited by Machine accuracy - return current minimum
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 86
#     Fit data ...
# W DavidonErrorUpdator delgam < 0 : first derivatives increasing along search line (details in info log)
# W VariableMetricBuilder Matrix not pos.def, gdel = 0.000141438 > 0
# W MnPosDef non-positive diagonal element in covariance matrix[ 0 ] = -0.000224608
# W MnPosDef Added to diagonal of Error matrix a value 0.500225
# W VariableMetricBuilder gdel = -8.25903
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Edm is limited by Machine accuracy - return current minimum
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.000619804 is smaller than machine limit 0.405074 while 0.0002 was requested
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 87
#     Fit data ...
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.00176382 is smaller than machine limit 0.403498 while 0.0002 was requested
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 88
#     Fit data ...
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.00156531 is smaller than machine limit 0.404033 while 0.0002 was requested
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 89
#     Fit data ...
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.00453627 is smaller than machine limit 0.404571 while 0.0002 was requested
# W VariableMetricBuilder No convergence; Edm 0.00453627 is above tolerance 0.002
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 90
#     Fit data ...
# W DavidonErrorUpdator delgam < 0 : first derivatives increasing along search line (details in info log)
# W MnPosDef Matrix forced pos-def by adding to diagonal 0.106937
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Edm is limited by Machine accuracy - return current minimum
# W MnPosDef Matrix forced pos-def by adding to diagonal 0.143912
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.125008 is smaller than machine limit 0.404673 while 0.0002 was requested
# W VariableMetricBuilder No convergence; Edm 0.125008 is above tolerance 0.002
# W MnPosDef Matrix forced pos-def by adding to diagonal 0.148992
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Edm is limited by Machine accuracy - return current minimum
# W MnPosDef Matrix forced pos-def by adding to diagonal 0.152126
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.00102426 is smaller than machine limit 0.404673 while 0.0002 was requested
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 91
#     Fit data ...
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.000562396 is smaller than machine limit 0.404141 while 0.0002 was requested
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 92
#     Fit data ...
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.000609046 is smaller than machine limit 0.404714 while 0.0002 was requested
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 93
#     Fit data ...
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.0014965 is smaller than machine limit 0.404238 while 0.0002 was requested
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 94
#     Fit data ...
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.00092782 is smaller than machine limit 0.404318 while 0.0002 was requested
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 95
#     Fit data ...
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.000284729 is smaller than machine limit 0.404757 while 0.0002 was requested
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 96
#     Fit data ...
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.00586646 is smaller than machine limit 0.405091 while 0.0002 was requested
# W VariableMetricBuilder No convergence; Edm 0.00586646 is above tolerance 0.002
# W DavidonErrorUpdator delgam < 0 : first derivatives increasing along search line (details in info log)
# W VariableMetricBuilder Matrix not pos.def, gdel = 0.000160918 > 0
# W MnPosDef Matrix forced pos-def by adding to diagonal 0.36079
# W VariableMetricBuilder gdel = -0.000124193
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 97
#     Fit data ...
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.000973273 is smaller than machine limit 0.405063 while 0.0002 was requested
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 98
#     Fit data ...
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.00113435 is smaller than machine limit 0.40457 while 0.0002 was requested
#     Calculate flux points ...
#     Plot spectra ...
#   Read events: 99
#     Fit data ...
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.000225101 is smaller than machine limit 0.404396 while 0.0002 was requested
#     Calculate flux points ...
#     Plot spectra ...
# CPU times: user 56min 14s, sys: 24min 51s, total: 1h 21min 6s
# Wall time: 1h 28min 17s

# %%
rows = []

path = (BASE_PATH / f"{Nsim}sims/best-fit")

for j in np.array([exp]):           # for every exposure
    ext = int(j)
    print(f"Exposure time: {ext} hr")
    for filename in path.glob(f"{MainSource}*{ext}hr*best-fit*.yaml"):
        print(filename)
        model_best_fit = Models.read(filename)        #we read the best fit model for every simulation
        row = {}
        for par in model_best_fit[f'{MainSourceAn}'].spectral_model.parameters:   #we consider the spectral parameters for every sim
            row[par.name] = par.value
            row[par.name + "_err"] = par.error
            
        rows.append(row)
        print(row)
    
    table = Table(rows)
    print('###################################################################')
    print(table)
    filename = f"{Nsim}sims/best-fit/{MainSource}_{ext}hr_results.fits"
    table.write(str(filename), overwrite=True)
# Out:
# /var/folders/d2/vc9_lbj902b8n1wlkbw8c1mr0000gn/T/ipykernel_37726/572331785.py:6: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ext = int(j)
# Exposure time: 50 hr
# 100sims/best-fit/NGC1068_50hr_best-fit_32.yaml
# {'index': 2.3586946769329558, 'index_err': 0.1534062897183429, 'amplitude': 5.2503233618310315e-14, 'amplitude_err': 9.333923821629479e-15, 'reference': 1.0, 'reference_err': 0.0}
# 100sims/best-fit/NGC1068_50hr_best-fit_65.yaml
# {'index': 2.437908810888005, 'index_err': 0.1698652475542337, 'amplitude': 4.770407918350294e-14, 'amplitude_err': 1.0426254110196742e-14, 'reference': 1.0, 'reference_err': 0.0}
# 100sims/best-fit/NGC1068_50hr_best-fit_73.yaml
# {'index': 2.419081287244946, 'index_err': 0.1358968318301359, 'amplitude': 5.751100773041871e-14, 'amplitude_err': 1.0058891033953417e-14, 'reference': 1.0, 'reference_err': 0.0}
# 100sims/best-fit/NGC1068_50hr_best-fit_24.yaml
# {'index': 2.4181397679706347, 'index_err': 0.14705263532633, 'amplitude': 6.10857161699112e-14, 'amplitude_err': 1.0378807050130611e-14, 'reference': 1.0, 'reference_err': 0.0}
# 100sims/best-fit/NGC1068_50hr_best-fit_49.yaml
# {'index': 2.234294510252499, 'index_err': 0.12927967233465984, 'amplitude': 5.627219475411475e-14, 'amplitude_err': 9.723014477007488e-15, 'reference': 1.0, 'reference_err': 0.0}
# 100sims/best-fit/NGC1068_50hr_best-fit_86.yaml
# {'index': 2.571395273085563, 'index_err': 0.16563786552164683, 'amplitude': 5.925021283915118e-14, 'amplitude_err': 1.2896329589213241e-14, 'reference': 1.0, 'reference_err': 0.0}
# 100sims/best-fit/NGC1068_50hr_best-fit
# 2.4217979765215287 0.10678589203620428 ...       1.0           0.0
#  2.222751959995819 0.11546436754776213 ...       1.0           0.0
#  2.322624352684741 0.11025950712422479 ...       1.0           0.0
#  2.306566050298987 0.12642390192802114 ...       1.0           0.0
# Length = 100 rows

# %%
import scipy.optimize as optimization

def gaussian(x,norm,m,s):
    g = norm * np.exp(-0.5 * ((x-m)/s)**2)
    return g

# %%
temp = np.array([exp])
par = np.array(['index','amplitude'])
Res_mean = []
Res_sigma = []

for j in temp:              #for every exposure time
    ext = int(j)
    result = table.read(f"./{Nsim}sims/best-fit/{MainSource}_{ext}hr_results.fits")
    for name in par:        #loop over the parameters to be computed
        mean = np.mean(result[name])
        sigma = np.sqrt(np.var(result[name]))
        Res_mean.append(mean)
        Res_sigma.append(sigma)
            #fig = plt.figure()
            #n, bins, patches = plt.hist(result[name], bins=15, density=True)
        figure, axs = plt.subplots(1, 2)
        n, bins, patches = axs[0].hist(result[name], bins=15, density=True)
        x = np.linspace(mean - 3*sigma, mean + 3*sigma, 100)
            #plt.figure()
            #plt.plot(x, gaussian(x, np.mean(n), mean, sigma), label=f"{mean} +\- {sigma}")
        axs[1].plot(x, gaussian(x, np.mean(n), mean, sigma), label=f"{mean} +\- {sigma}")
        plt.legend()
        filename = f"./{Nsim}sims/best-fit/{MainSource}_{name}_{ext}hr_hist.png"

print(Res_mean)
print(Res_sigma)
# Out:
# /var/folders/d2/vc9_lbj902b8n1wlkbw8c1mr0000gn/T/ipykernel_37726/1741344689.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ext = int(j)
# [np.float64(2.396606126384222), np.float64(6.133757710773796e-14)]
# [np.float64(0.12172718260889802), np.float64(1.0354607284118611e-14)]

# %%
e_bins = 10    #spectral bins
path = BASE_PATH / f"{Nsim}sims/spectra/"

### Creation of paramter arrays with dimensions=number of exposure times
flux = np.zeros((len(temp),e_bins-1,Nsim), float)
sqrt_ts = np.zeros((len(temp),e_bins-1,Nsim), float)
ts = np.zeros((len(temp),e_bins-1,Nsim), float)

for k in np.arange(len(temp)):           # for every exposure time
    j=0
    for filename in path.glob(f"{MainSource}_{ext}hr_spectrum*.fits"): # for every simulation
        for i in np.arange(e_bins-1):                 #for every energy bin
            tab = Table.read(filename, hdu=1)
            tab['ref_dnde'] = tab['ref_dnde'].quantity.to("1 / (TeV s cm2)")
            if str(tab['ref_dnde'][i]) != 'nan':
                flux[k,i,j] = tab['ref_dnde'][i]
                sqrt_ts[k,i,j] = tab['sqrt_ts'][i]
                ts[k,i,j] = tab['ts'][i]
            else:
                flux[k,i,j] = tab['ref_dnde'][i]
                sqrt_ts[k,i,j] = tab['sqrt_ts'][i]
                ts[k,i,j] = tab['ts'][i]
        j += 1 
print('Flux')
print(flux)
print('sqrt_TS')
print(sqrt_ts)
print('TS')
print(ts)

sqrt_ts[np.isnan(sqrt_ts)] = 0                #if we have a NAN, put in 0
# Out:
# Flux
# [[[8.50605767e-12 5.97817798e-12 8.26050422e-12 7.82110896e-12
#    7.64592084e-12 1.10544269e-11 7.57596538e-12 4.58945967e-12
#    3.20028853e+00 2.90219468e+00 7.51318266e-01 2.98750644e+00
#    6.57201672e+00 2.58339653e+00 3.29647624e+00 5.43077503e-01
#    3.34500043e+00 3.56237336e-01 4.26511503e-01 2.11947316e+00
#    2.25108886e+00 1.87942562e+00 5.83587597e-01 9.07907664e+00
#    5.48993028e-01 9.98376328e-01 9.59533243e-02 7.22176078e-01]
#   [1.71634065e-01 3.13160602e+00 8.47965440e-01 2.20249907e+00
#    1.22557136e-01 1.08650568e+00 2.85726312e-02 1.49363880e+00
#    2.40067977e+00 3.19664203e+00 3.77139903e+00 9.68205166e-02
#    3.52112328e+00 5.83726057e+00 2.49534532e-01 2.08629412e+00
#    1.37781925e+00 5.49771769e-01 2.49412121e+00 2.79350085e-01
#    2.09508085e+00 2.99943760e-01 7.18543443e-01 4.77867157e+00
#    1.02063976e+00 7.03397474e-01 5.39474551e-01 1.47755405e+00
#    1.01048424e+00 1.95018831e-04 1.48614684e+00 1.99939933e+00
#    6.28993811e-01 7.71751633e-01 2.39221160e+00 1.49362448e+00
#    3.34044702e-01 5.86961361e-01 2.52863713e+00 1.94733147e+00
#    5.18464963e-01 4.24651722e+00 2.70053176e+00 4.71147423e-01
#    7.35185734e-03 4.76754375e+00 5.30499629e+00 4.83557997e+00
#    3.55110659e+00 3.87977458e-01 8.84175034e-01 7.16494767e-01
#    5.94397904e+00 2.67502143e-01 7.68722868e-01 3.75176158e+00
#    4.17636622e-01 9.94481047e-02 2.71636058e-01 4.15105284e-02
#    3.15752587e+00 3.32760209e-02 7.99758450e-02 1.20301887e+00
#    1.64896249e+00 2.08627041e-01 9.34145044e-01 4.39733905e+00
#    2.65442424e+00 2.72945027e-01 1.27900899e-01 2.34863294e+00
#    9.41609482e-02 1.19905479e-01 1.34600005e+00 3.32368863e+00
#    1.85711655e-01 1.26252066e+00 2.48118491e-01 3.90287309e-01
#    4.45474182e-01 6.17494942e-01 2.49330253e-01 3.43554159e+00
#    1.08887260e+00 3.87537041e+00 9.72358632e-03 1.58767184e+00
#    2.83929613e-01 1.36019045e+00 1.82896934e-01 6.53375180e-01
#    1.64624687e-01 1.33528180e+00 2.23652888e+00 8.76970125e-01
#    3.29248782e+00 4.45999994e+00 3.98522802e+00 9.83646183e-01]]]

# %%
import pandas as pd
path = (BASE_PATH / f"{Nsim}sims/best-fit")

for k in np.arange(len(temp)):       #for every exposure time
    e_ref = []
    e_min_ar = []
    e_max_ar = []
    dnde = []
    dnde_ul = []    
    dnde_err = []
    is_ul = []
    for i in np.arange(e_bins-1):    # for every energy bin
        print('The TS mean is:', np.mean(ts[k,i]))
        if np.mean(sqrt_ts[k,i])>=2.5:                 # the condition is always on the average of the TS (usually 9)
            mean = np.mean(flux[k,i])
            sigma = np.sqrt(np.var(flux[k,i]))
            e_ref.append(tab['e_ref'][i])
            e_min_ar.append(tab['e_min'][i])
            e_max_ar.append(tab['e_max'][i])
            dnde.append(mean)
            dnde_ul.append(mean)
            dnde_err.append(sigma)
            is_ul.append(False)

        else:
            e_ref.append(tab['e_ref'][i])
            e_min_ar.append(tab['e_min'][i])
            e_max_ar.append(tab['e_max'][i])
            dnde.append(np.max(stats.norm.interval(0.95, loc=mean, scale=sigma)))
            dnde_ul.append(np.max(stats.norm.interval(0.95, loc=mean, scale=sigma)))
            dnde_err.append(np.max(stats.norm.interval(0.95, loc=mean, scale=sigma)))
            is_ul.append(True)
#when the TS distribution was not significant in a given energy bin, we calculated a 95% confidence
#level upper limit on flux from the distribution of the simulated fluxes.

    a = Table()
    a['e_min'] = e_min_ar * u.TeV
    a['e_max'] = e_max_ar * u.TeV
    a['e_ref'] = e_ref * u.TeV
    a['dnde'] = dnde 
    a['dnde'].unit = 'cm^-2 s^-1 TeV^-1'
    a['dnde_ul'] = dnde_ul 
    a['dnde_ul'].unit = 'cm^-2 s^-1 TeV^-1'
    a['dnde_err'] = dnde_err
    a['dnde_err'].unit = 'cm^-2 s^-1 TeV^-1'
    a['is_ul'] = is_ul
    a.meta["SED_TYPE"]="dnde    "
    
    filename=path / f'{MainSource}_{temp[k]}hr_average_spectrum.fits'
    a.write(filename, overwrite='True')
# Out:
# The TS mean is: 3.794464815706015
# The TS mean is: 11.03265042866231
# The TS mean is: 12.070711264669661
# The TS mean is: 12.33322208779864
# The TS mean is: 12.688800108196446
# The TS mean is: 6.0722968211382975
# The TS mean is: 2.612312913018104
# The TS mean is: 1.4995378022489603
# The TS mean is: 1.568747716869766

# %%
temp = np.array([ext])
path = (BASE_PATH / f"{Nsim}sims/best-fit")
for k in np.arange(len(temp)):
    filename=path / f'{MainSource}_{temp[k]}hr_average_spectrum.fits'
    dati = FluxPoints.read(filename)
    ax = dataset_original[0].spectral_model.plot(            #input model
        energy_bounds=[e_min, e_max] * u.TeV, 
        sed_type="e2dnde",
        label="Sim. model", 
        color='black'
        )
    
    #We need to overlap the average model obtained by all the best-fit models
    dataset_mean = Models.read("/Users/tharacaba/Desktop/Tesis_2/MASS_Thesis/simulations/Fermi/NGC1068_PL.yaml") 

    dataset_mean[0].spectral_model.parameters[0].value = Res_mean[0]
    dataset_mean[0].spectral_model.parameters[0].error = Res_sigma[0]
    dataset_mean[0].spectral_model.parameters[1].value = Res_mean[1]
    dataset_mean[0].spectral_model.parameters[1].error = Res_sigma[1]
    # dataset_mean[0].spectral_model.lambda_.value = Res_mean[2]
    # dataset_mean[0].spectral_model.lambda_.error = Res_sigma[2]

    px = {"color": "red", "marker":"o"}
    mx = {"color": "blue"}

    flux_points_dataset = FluxPointsDataset(data=dati, models=dataset_mean[0])
    flux_points_dataset.plot_spectrum(ax=ax, kwargs_fp=px, kwargs_model=mx)
    ax.legend()
    #ax.set_ylim(1.e-15,1e-11)
filename = path / f'{MainSource}_{temp[k]}hr_average_spectrum.png'
#    save_figure(filename)
# Out:
# No reference model set for FluxMaps. Assuming point source with E^-2 spectrum.

# %%
print(dataset_mean[0].spectral_model)
# Out:
# PowerLawSpectralModel
#
# type    name     value         unit        error   min max frozen link prior
# ---- --------- ---------- -------------- --------- --- --- ------ ---- -----
#          index 2.3966e+00                1.217e-01 nan nan  False
#      amplitude 6.1338e-14 TeV-1 s-1 cm-2 1.035e-14 nan nan  False
#      reference 1.0000e+00            TeV 0.000e+00 nan nan   True

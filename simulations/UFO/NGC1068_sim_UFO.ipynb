# %% [markdown]
# # CTAO Simulation of NGC 1068 with Peretti+ 2023 UF0 Model

# %%
# Imports
import numpy as np

import glob, os, itertools

from astropy.coordinates import SkyCoord, Angle
import astropy.units as u
from astropy.time import Time
from astropy.table import Table
from astropy.io import ascii

import matplotlib.pyplot as plt 

from regions import CircleSkyRegion

from gammapy.data import Observation, observatory_locations, FixedPointingInfo, DataStore
from gammapy.irf import load_irf_dict_from_file
from gammapy.maps import MapAxis, RegionGeom, WcsGeom, Map
from gammapy.datasets import SpectrumDataset, Datasets, FluxPointsDataset, MapDataset, MapDatasetEventSampler
from gammapy.makers import SpectrumDatasetMaker, SafeMaskMaker, ReflectedRegionsBackgroundMaker, MapDatasetMaker
from gammapy.modeling import Fit
from gammapy.modeling.models import (SkyModel, EBLAbsorptionNormSpectralModel, PointSpatialModel, ExpCutoffPowerLawSpectralModel, FoVBackgroundModel, Models, 
                                     PowerLawSpectralModel, LogParabolaSpectralModel, SmoothBrokenPowerLawSpectralModel, TemplateSpectralModel)
from gammapy.catalog import CATALOG_REGISTRY
from gammapy.estimators import FluxPointsEstimator
from gammapy.visualization import plot_spectrum_datasets_off_regions

# %% [markdown]
# To simulate the spectrum of our source we first need to create the source with an input model. Afterwards we create an observation from the Cherenkov Telescope Array Observatory (CTAO). The format of this data needs to be 3 dimensional. After creating the observation we simulate the events and input them into the observation. We then do an standard spectral analysis with the simulated data and finally perform a fitting.

# %% [markdown]
# ## Simulations of multiple observations

# %% [markdown]
# We can simulate the same sources for a number of observations, where the starting time and the livetime are changing. We are going to simulate the source for N observations, with a random cadence between them.

# %% [markdown]
# ### Creating our Source

# %%
target_position = SkyCoord(40.669 * u.deg, -0.013 * u.deg, frame="icrs", unit="deg")

# Template spectral model. Defined by custom tabular values from Peretti+ 2023
data = ascii.read("Peretti_2023_UFO.dat")

energy_bounds = [0.0001, 100] * u.TeV
energy = data['Energy[MeV]'] *u.MeV
values = data['flux[MeV^-1cm^-2s^-1]'] *1.0 / (u.MeV * u.cm **2.0 * u.s)

template_spec_model = TemplateSpectralModel(energy=energy, values=values)
template_spec_model.plot(energy_bounds, sed_type="e2dnde")
plt.grid(which="both")

# Getting the background
bkg_model = FoVBackgroundModel(dataset_name="my-dataset")

# Creating the satial model
spatial_model = PointSpatialModel.from_position(target_position)

# %% [markdown]
# ### Creating the Dataset

# %%
# Ereco and Etrue must to be different: Etrue must have a larger range in order to reconstruct in the correct way (knowledge of the whole photon energy extension)
energy_axis = MapAxis.from_energy_bounds(
    "0.1 TeV", "100 TeV", nbin=10, per_decade=True
    )

# for the Edisp
energy_axis_true = MapAxis.from_energy_bounds(
    "0.01 TeV", "200 TeV", nbin=20, per_decade=True, name="energy_true"
    )

migra_axis = MapAxis.from_bounds(
    0.5, 2, nbin=150, node_type="edges", name="migra" # If node_type = ‘edge’ then bounds correspond to the lower
                                                      # and upper bound of the first and last bin.
    )

pointing = FixedPointingInfo(
    fixed_icrs= SkyCoord(40.169 * u.deg, -0.013 * u.deg, frame="icrs", unit="deg"),
) # A bit offset from source position

# let's define the geometry of the simulation:
geom = WcsGeom.create(
    skydir=pointing.fixed_icrs,           
    width=(4, 4),         # gammapy uses a square not a circle 
    binsz=0.02,           # pixel size
    frame="icrs",
    axes=[energy_axis],    # in reco energy
)    

# MapDataset object with zer0-filled map
empty = MapDataset.create(
        geom,                               
        energy_axis_true=energy_axis_true,       # for the IRF maps
        migra_axis=migra_axis,                   # for the Edisp map
        name="my-dataset",                       # the name that will read the FoVBKG
            )

maker = MapDatasetMaker(selection=["exposure", "background", "psf", "edisp"]) # which maps to make (by default all)

# %% [markdown]
# ### Running Simulation

# %%
# Parameters
total_hours = 124
obs_duration = 0.5  # 30 minutes in hours
n_obs = int(total_hours / obs_duration)

# Generate tstart_obs with increasing values (non-simultaneous), spread out in time
# We use an arbitrary starting point and step to ensure separation
tstart_obs = np.linspace(0.083, 5, n_obs) * u.d

# All observations are 30 minutes
livetime_obs = np.full(n_obs, obs_duration) * u.hr

# Generate angle_wobble cycling through [0, 90, 180, 270]
base_angles = [0, 90, 180, 270]
angle_wobble = [base_angles[i % 4] for i in range(n_obs)] * u.deg

# Combine into a table for visualization
obs_table = Table(
    [tstart_obs, livetime_obs, angle_wobble],
    names=["tstart_obs", "livetime_obs", "angle_wobble"]
)

# Print the first few observations to verify
print(obs_table[:10])

# Verification checks
print("\nTotal livetime (hr):", np.sum(livetime_obs))
print("Number of observations:", n_obs)
# Out:
#      tstart_obs     livetime_obs angle_wobble
#          d               h           deg
# ------------------- ------------ ------------
#               0.083          0.5          0.0
# 0.10290688259109312          0.5         90.0
# 0.12281376518218623          0.5        180.0
# 0.14272064777327936          0.5        270.0
# 0.16262753036437247          0.5          0.0
# 0.18253441295546557          0.5         90.0
#  0.2024412955465587          0.5        180.0
# 0.22234817813765184          0.5        270.0
# 0.24225506072874492          0.5          0.0
# 0.26216194331983805          0.5         90.0
#
# Total livetime (hr): 124.0 h
# Number of observations: 248

# %%
# Get all files in the ./sims directory
files = glob.glob('./sims/*')

# Loop and delete each file
for f in files:
    if os.path.isfile(f):
        os.remove(f)
        print(f"Deleted file: {f}")
# Out:
# Deleted file: ./sims/events_obs150.fits
# Deleted file: ./sims/events_obs107.fits
# Deleted file: ./sims/events_obs55.fits
# Deleted file: ./sims/events_obs111.fits
# Deleted file: ./sims/events_obs238.fits
# Deleted file: ./sims/events_obs43.fits
# Deleted file: ./sims/events_obs146.fits
# Deleted file: ./sims/events_obs14.fits
# Deleted file: ./sims/events_obs80.fits
# Deleted file: ./sims/events_obs214.fits
# Deleted file: ./sims/events_obs185.fits
# Deleted file: ./sims/events_obs38.fits
# Deleted file: ./sims/events_obs243.fits
# Deleted file: ./sims/events_obs193.fits
# Deleted file: ./sims/events_obs0.fits
# Deleted file: ./sims/events_obs79.fits
# Deleted file: ./sims/events_obs202.fits
# Deleted file: ./sims/events_obs96.fits
# Deleted file: ./sims/events_obs222.fits
# Deleted file: ./sims/events_obs59.fits
# Deleted file: ./sims/events_obs234.fits
# Deleted file: ./sims/events_obs18.fits
# Deleted file: ./sims/events_obs63.fits
# Deleted file: ./sims/events_obs218.fits
# Deleted file: ./sims/events_obs131.fits
# Deleted file: ./sims/events_obs34.fits
# Deleted file: ./sims/events_obs166.fits
# Deleted file: ./sims/events_obs189.fits
# Deleted file: ./sims/events_obs22.fits
# Deleted file: ./sims/events_obs170.fits
# Deleted file: ./sims/events_obs75.fits
# Deleted file: ./sims/events_obs127.fits
# Deleted file: ./sims/events_obs126.fits
# Deleted file: ./sims/events_obs74.fits
# Deleted file: ./sims/events_obs171.fits
# Deleted file: ./sims/events_obs23.fits
# Deleted file: ./sims/events_obs167.fits
# Deleted file: ./sims/events_obs188.fits
# Deleted file: ./sims/events_obs35.fits
# Deleted file: ./sims/events_obs130.fits
# Deleted file: ./sims/events_obs62.fits
# Deleted file: ./sims/events_obs219.fits
# Deleted file: ./sims/events_obs19.fits
# Deleted file: ./sims/events_obs235.fits
# Deleted file: ./sims/events_obs223.fits
# Deleted file: ./sims/events_obs58.fits
# Deleted file: ./sims/events_obs78.fits
# Deleted file: ./sims/events_obs97.fits
# Deleted file: ./sims/events_obs203.fits
# Deleted file: ./sims/events_obs1.fits
# Deleted file: ./sims/events_obs192.fits
# Deleted file: ./sims/events_obs39.fits
# Deleted file: ./sims/events_obs242.fits
# Deleted file: ./sims/events_obs184.fits
# Deleted file: ./sims/events_obs215.fits
# Deleted file: ./sims/events_obs81.fits
# Deleted file: ./sims/events_obs15.fits
# Deleted file: ./sims/events_obs147.fits
# Deleted file: ./sims/events_obs239.fits
# Deleted file: ./sims/events_obs42.fits
# Deleted file: ./sims/events_obs110.fits
# Deleted file: ./sims/events_obs54.fits
# Deleted file: ./sims/events_obs106.fits
# Deleted file: ./sims/events_obs151.fits
# Deleted file: ./sims/events_obs224.fits
# Deleted file: ./sims/events_obs232.fits
# Deleted file: ./sims/events_obs49.fits
# Deleted file: ./sims/events_obs65.fits
# Deleted file: ./sims/events_obs137.fits
# Deleted file: ./sims/events_obs32.fits
# Deleted file: ./sims/events_obs160.fits
# Deleted file: ./sims/events_obs24.fits
# Deleted file: ./sims/events_obs176.fits
# Deleted file: ./sims/events_obs199.fits
# Deleted file: ./sims/events_obs73.fits
# Deleted file: ./sims/events_obs208.fits
# Deleted file: ./sims/events_obs121.fits
# Deleted file: ./sims/events_obs156.fits
# Deleted file: ./sims/events_obs101.fits
# Deleted file: ./sims/events_obs228.fits
# Deleted file: ./sims/events_obs53.fits
# Deleted file: ./sims/events_obs117.fits
# Deleted file: ./sims/events_obs45.fits
# Deleted file: ./sims/events_obs140.fits
# Deleted file: ./sims/events_obs12.fits
# Deleted file: ./sims/events_obs69.fits
# Deleted file: ./sims/events_obs86.fits
# Deleted file: ./sims/events_obs212.fits
# Deleted file: ./sims/events_obs183.fits
# Deleted file: ./sims/events_obs245.fits
# Deleted file: ./sims/events_obs195.fits
# Deleted file: ./sims/events_obs28.fits
# Deleted file: ./sims/events_obs6.fits
# Deleted file: ./sims/events_obs204.fits
# Deleted file: ./sims/events_obs90.fits
# Deleted file: ./sims/events_obs91.fits
# Deleted file: ./sims/events_obs205.fits
# Deleted file: ./sims/events_obs7.fits
# Deleted file: ./sims/events_obs29.fits
# Deleted file: ./sims/events_obs194.fits
# Deleted file: ./sims/events_obs244.fits
# Deleted file: ./sims/events_obs182.fits
# Deleted file: ./sims/events_obs68.fits
# Deleted file: ./sims/events_obs213.fits
# Deleted file: ./sims/events_obs87.fits
# Deleted file: ./sims/events_obs13.fits
# Deleted file: ./sims/events_obs141.fits
# Deleted file: ./sims/events_obs44.fits
# Deleted file: ./sims/events_obs116.fits
# Deleted file: ./sims/events_obs229.fits
# Deleted file: ./sims/events_obs52.fits
# Deleted file: ./sims/events_obs100.fits
# Deleted file: ./sims/events_obs157.fits
# Deleted file: ./sims/events_obs120.fits
# Deleted file: ./sims/events_obs72.fits
# Deleted file: ./sims/events_obs209.fits
# Deleted file: ./sims/events_obs177.fits
# Deleted file: ./sims/events_obs198.fits
# Deleted file: ./sims/events_obs25.fits
# Deleted file: ./sims/events_obs161.fits
# Deleted file: ./sims/events_obs33.fits
# Deleted file: ./sims/events_obs136.fits
# Deleted file: ./sims/events_obs64.fits
# Deleted file: ./sims/events_obs233.fits
# Deleted file: ./sims/events_obs48.fits
# Deleted file: ./sims/events_obs225.fits
# Deleted file: ./sims/events_obs8.fits
# Deleted file: ./sims/events_obs123.fits
# Deleted file: ./sims/events_obs71.fits
# Deleted file: ./sims/events_obs174.fits
# Deleted file: ./sims/events_obs26.fits
# Deleted file: ./sims/events_obs162.fits
# Deleted file: ./sims/events_obs30.fits
# Deleted file: ./sims/events_obs135.fits
# Deleted file: ./sims/events_obs88.fits
# Deleted file: ./sims/events_obs67.fits
# Deleted file: ./sims/events_obs119.fits
# Deleted file: ./sims/events_obs230.fits
# Deleted file: ./sims/events_obs226.fits
# Deleted file: ./sims/events_obs158.fits
# Deleted file: ./sims/events_obs92.fits
# Deleted file: ./sims/events_obs206.fits
# Deleted file: ./sims/events_obs4.fits
# Deleted file: ./sims/events_obs197.fits
# Deleted file: ./sims/events_obs178.fits
# Deleted file: ./sims/events_obs181.fits
# Deleted file: ./sims/events_obs210.fits
# Deleted file: ./sims/events_obs84.fits
# Deleted file: ./sims/events_obs139.fits
# Deleted file: ./sims/events_obs10.fits
# Deleted file: ./sims/events_obs142.fits
# Deleted file: ./sims/events_obs47.fits
# Deleted file: ./sims/events_obs115.fits
# Deleted file: ./sims/events_obs51.fits
# Deleted file: ./sims/events_obs103.fits
# Deleted file: ./sims/events_obs154.fits
# Deleted file: ./sims/events_obs155.fits
# Deleted file: ./sims/events_obs102.fits
# Deleted file: ./sims/events_obs50.fits
# Deleted file: ./sims/events_obs114.fits
# Deleted file: ./sims/events_obs46.fits
# Deleted file: ./sims/events_obs143.fits
# Deleted file: ./sims/events_obs11.fits
# Deleted file: ./sims/events_obs138.fits
# Deleted file: ./sims/events_obs85.fits
# Deleted file: ./sims/events_obs211.fits
# Deleted file: ./sims/events_obs180.fits
# Deleted file: ./sims/events_obs196.fits
# Deleted file: ./sims/events_obs179.fits
# Deleted file: ./sims/events_obs5.fits
# Deleted file: ./sims/events_obs207.fits
# Deleted file: ./sims/events_obs93.fits
# Deleted file: ./sims/events_obs159.fits
# Deleted file: ./sims/events_obs227.fits
# Deleted file: ./sims/events_obs231.fits
# Deleted file: ./sims/events_obs118.fits
# Deleted file: ./sims/events_obs89.fits
# Deleted file: ./sims/events_obs66.fits
# Deleted file: ./sims/events_obs134.fits
# Deleted file: ./sims/events_obs31.fits
# Deleted file: ./sims/events_obs163.fits
# Deleted file: ./sims/events_obs27.fits
# Deleted file: ./sims/events_obs175.fits
# Deleted file: ./sims/events_obs70.fits
# Deleted file: ./sims/events_obs9.fits
# Deleted file: ./sims/events_obs122.fits
# Deleted file: ./sims/events_obs94.fits
# Deleted file: ./sims/events_obs200.fits
# Deleted file: ./sims/events_obs2.fits
# Deleted file: ./sims/events_obs129.fits
# Deleted file: ./sims/events_obs191.fits
# Deleted file: ./sims/events_obs241.fits
# Deleted file: ./sims/events_obs187.fits
# Deleted file: ./sims/events_obs168.fits
# Deleted file: ./sims/events_obs216.fits
# Deleted file: ./sims/events_obs82.fits
# Deleted file: ./sims/events_obs16.fits
# Deleted file: ./sims/events_obs144.fits
# Deleted file: ./sims/events_obs41.fits
# Deleted file: ./sims/events_obs113.fits
# Deleted file: ./sims/events_obs57.fits
# Deleted file: ./sims/events_obs105.fits
# Deleted file: ./sims/events_obs152.fits
# Deleted file: ./sims/events_obs125.fits
# Deleted file: ./sims/events_obs98.fits
# Deleted file: ./sims/events_obs77.fits
# Deleted file: ./sims/events_obs172.fits
# Deleted file: ./sims/events_obs20.fits
# Deleted file: ./sims/events_obs164.fits
# Deleted file: ./sims/events_obs36.fits
# Deleted file: ./sims/events_obs133.fits
# Deleted file: ./sims/events_obs61.fits
# Deleted file: ./sims/events_obs148.fits
# Deleted file: ./sims/events_obs236.fits
# Deleted file: ./sims/events_obs109.fits
# Deleted file: ./sims/events_obs220.fits
# Deleted file: ./sims/events_obs221.fits
# Deleted file: ./sims/events_obs108.fits
# Deleted file: ./sims/events_obs237.fits
# Deleted file: ./sims/events_obs149.fits
# Deleted file: ./sims/events_obs60.fits
# Deleted file: ./sims/events_obs132.fits
# Deleted file: ./sims/events_obs37.fits
# Deleted file: ./sims/events_obs165.fits
# Deleted file: ./sims/events_obs21.fits
# Deleted file: ./sims/events_obs173.fits
# Deleted file: ./sims/events_obs99.fits
# Deleted file: ./sims/events_obs76.fits
# Deleted file: ./sims/events_obs124.fits
# Deleted file: ./sims/events_obs153.fits
# Deleted file: ./sims/events_obs104.fits
# Deleted file: ./sims/events_obs56.fits
# Deleted file: ./sims/events_obs112.fits
# Deleted file: ./sims/events_obs40.fits
# Deleted file: ./sims/events_obs145.fits
# Deleted file: ./sims/events_obs17.fits
# Deleted file: ./sims/events_obs83.fits
# Deleted file: ./sims/events_obs217.fits
# Deleted file: ./sims/events_obs186.fits
# Deleted file: ./sims/events_obs169.fits
# Deleted file: ./sims/events_obs240.fits
# Deleted file: ./sims/events_obs190.fits
# Deleted file: ./sims/events_obs3.fits
# Deleted file: ./sims/events_obs128.fits
# Deleted file: ./sims/events_obs201.fits
# Deleted file: ./sims/events_obs95.fits

# %%
# The telescopes Instrument Response Function
irf_filename = "/Users/tharacaba/Desktop/Tesis_2/gammapy-datasets/1.3/cta-prod5-zenodo-fitsonly-v0/fits/CTA-Performance-prod5-v0.1-North-40deg.FITS/Prod5-North-40deg-AverageAz-4LSTs09MSTs.180000s-v0.1.fits"  
IRF = load_irf_dict_from_file(irf_filename)

# Parameters for observation
location = observatory_locations["cta_north"]
reference_time = Time("2026-05-28T00:00:00", format="isot", scale="utc")

# Model of our source
sky_model = SkyModel(
                    spectral_model=template_spec_model,
                    spatial_model=spatial_model,
                    name="NGC_1068",
                    )

model_obs = Models([sky_model, bkg_model])

dataset_original = model_obs.copy()        # We need it for spectrum plot

print(model_obs)
# Out:
# Models
#
# Component 0: SkyModel
#
#   Name                      : NGC_1068
#   Datasets names            : None
#   Spectral model type       : TemplateSpectralModel
#   Spatial  model type       : PointSpatialModel
#   Temporal model type       :
#   Parameters:
#     lon_0                         :     40.669   +/-    0.00 deg
#     lat_0                         :     -0.013   +/-    0.00 deg
#
# Component 1: FoVBackgroundModel
#
#   Name                      : my-dataset-bkg
#   Datasets names            : ['my-dataset']
#   Spectral model type       : PowerLawNormSpectralModel
#   Parameters:
#     norm                          :      1.000   +/-    0.00
#     tilt                  (frozen):      0.000
#     reference             (frozen):      1.000       TeV

# %%
# Simulating observations
for i, (tobs, liveobs, wobobs) in enumerate(zip(tstart_obs, livetime_obs, angle_wobble)):

    pointing_obs = target_position.directional_offset_by(wobobs, 0.5*u.deg)
    obs = Observation.create(
                            obs_id=i, 
                            pointing=pointing_obs, 
                            livetime=liveobs, 
                            irfs=IRF,
                            location=location,
                            reference_time = reference_time, 
                            tstart = tobs
                  )    

    dataset = maker.run(empty, obs) 
    dataset.models = model_obs

    sampler = MapDatasetEventSampler(random_state=0)
    events = sampler.run(dataset, obs)

    obs.events = events
    obs.write(f"./sims/events_obs{i}.fits", include_irfs=False, overwrite=True)
# Out:
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# ...
#   warnings.warn(
# The meta information will be empty here.
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/gammapy/data/observations.py:294: GammapyDeprecationWarning: Pointing will be required to be provided as FixedPointingInfo
#   warnings.warn(
# The meta information will be empty here.
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]

# %% [markdown]
# ### Verifications

# %%
# let's have a look at the events
events.peek()

# Focusing on our source
src_pos = SkyCoord(ra="40.669 deg", dec="-0.013 deg", 
                   frame="icrs")

region_sky = CircleSkyRegion(center=src_pos, radius=0.3 * u.deg)
evt = events.select_region(region_sky)
evt.peek()

# %% [markdown]
# ## Source Detection

# %% [markdown]
# We do a 1D spectral analysis.

# %% [markdown]
# ### Load our Data

# %%
input_filenames = []
input_filenames.append(glob.glob(os.path.join("./sims/", '*.fits')))
input_filenames = tuple(itertools.chain.from_iterable(input_filenames))

datastore = DataStore.from_events_files(np.sort(input_filenames), 
                                        irfs_paths="/Users/tharacaba/Desktop/Tesis_2/gammapy-datasets/1.3/cta-prod5-zenodo-fitsonly-v0/fits/CTA-Performance-prod5-v0.1-North-40deg.FITS/Prod5-North-40deg-AverageAz-4LSTs09MSTs.180000s-v0.1.fits")

observations = datastore.get_observations(obs_id=list(datastore.obs_table['OBS_ID']))

# %% [markdown]
# ### Spectral Analysis

# %%
target_position = SkyCoord(40.669 * u.deg, -0.013 * u.deg, frame="icrs", unit="deg")

# We consider a square map of size 2.0 deg, spatially binned with bins of 0.02 deg;
# We define the ON region, assuming a circle of 0.2 deg of radius, for the source;
width = 2.0  #deg
binsz = 0.02 #deg
radius= 0.2  #deg

# Let's define an exclusion region, in order to better estimate the bkg:
SkyCoord(40.669 * u.deg, -0.013 * u.deg, frame="icrs", unit="deg")
on_region_radius = Angle(radius * u.deg)
on_region = CircleSkyRegion(center=target_position, radius=on_region_radius)

npix = int(width/binsz)

exclusion_region = CircleSkyRegion(
    center=target_position,
    radius=radius * u.deg,
)

geom_excl = WcsGeom.create(
    npix=(npix, npix), binsz=binsz, skydir=target_position.galactic, proj="TAN", frame="galactic"
)

exclusion_mask = ~geom_excl.region_mask([exclusion_region])
exclusion_mask.plot()
plt.show()

# %%
# Create the reconstruced energy range:
e_min, e_max = 0.1 * u.TeV, 100 * u.TeV

energy_axis = MapAxis.from_energy_bounds(
    e_min, e_max, nbin=5, per_decade=True, unit="TeV", name="energy"
)

# Reduced IRFs are defined in true energy (i.e. not measured energy).
energy_axis_true = MapAxis.from_energy_bounds(
    0.01, 300, nbin=10, per_decade=True, unit="TeV", name="energy_true"
)

# Geometry defining the ON region and SpectrumDataset based on it
geom = RegionGeom.create(region=on_region, axes=[energy_axis])

dataset_empty = SpectrumDataset.create(geom=geom, energy_axis_true=energy_axis_true)

dataset_maker = SpectrumDatasetMaker(
    containment_correction=True, selection=["counts", "exposure", "edisp"]
)

# Tell the background maker to determine the reflected regions, excluding the source region:
maker_fov = ReflectedRegionsBackgroundMaker(exclusion_mask=exclusion_mask)

# Let's impone a safe range for the analysis: we consider only events at a distance from the pointing direction < 1 deg.
offset_max = 2 * u.deg
safe_mask_masker = SafeMaskMaker(
    methods=["aeff-default","offset-max"], offset_max=offset_max
)

# Create a counts map for visualisation later...
counts = Map.create(skydir=target_position, width=3)

# Let's create the dataset for each observation and stack them all:
datasets = Datasets()

# Let's loop over observations
for observation in observations:
    # generate a dataset object
    dataset = dataset_maker.run(
        dataset_empty.copy(name=str(observation.obs_id)), observation
    )
    # Fill the dataset with the events of the observation
    counts.fill_events(observation.events)

    # Calculate the bkg
    dataset_on_off = maker_fov.run(dataset, observation)
    # Set a safe range for the analysis
    dataset_on_off = safe_mask_masker.run(dataset_on_off, observation)

    datasets.append(dataset_on_off)
# Out:
# No default upper safe energy threshold defined for obs 0
# No default lower safe energy threshold defined for obs 0
# No default upper safe energy threshold defined for obs 1
# No default lower safe energy threshold defined for obs 1
# No default upper safe energy threshold defined for obs 10
# No default lower safe energy threshold defined for obs 10
# No default upper safe energy threshold defined for obs 100
# No default lower safe energy threshold defined for obs 100
# No default upper safe energy threshold defined for obs 101
# No default lower safe energy threshold defined for obs 101
# No default upper safe energy threshold defined for obs 102
# No default lower safe energy threshold defined for obs 102
# No default upper safe energy threshold defined for obs 103
# No default lower safe energy threshold defined for obs 103
# No default upper safe energy threshold defined for obs 104
# No default lower safe energy threshold defined for obs 104
# No default upper safe energy threshold defined for obs 105
# No default lower safe energy threshold defined for obs 105
# No default upper safe energy threshold defined for obs 106
# No default lower safe energy threshold defined for obs 106
# No default upper safe energy threshold defined for obs 107
# No default lower safe energy threshold defined for obs 107
# No default upper safe energy threshold defined for obs 108
# No default lower safe energy threshold defined for obs 108
# No default upper safe energy threshold defined for obs 109
# No default lower safe energy threshold defined for obs 109
# No default upper safe energy threshold defined for obs 11
# No default lower safe energy threshold defined for obs 11
# No default upper safe energy threshold defined for obs 110
# No default lower safe energy threshold defined for obs 110
# No default upper safe energy threshold defined for obs 111
# No default lower safe energy threshold defined for obs 111
# No default upper safe energy threshold defined for obs 112
# No default lower safe energy threshold defined for obs 112
# No default upper safe energy threshold defined for obs 113
# No default lower safe energy threshold defined for obs 113
# No default upper safe energy threshold defined for obs 114
# No default lower safe energy threshold defined for obs 114
# No default upper safe energy threshold defined for obs 115
# No default lower safe energy threshold defined for obs 115
# No default upper safe energy threshold defined for obs 116
# No default lower safe energy threshold defined for obs 116
# No default upper safe energy threshold defined for obs 117
# No default lower safe energy threshold defined for obs 117
# No default upper safe energy threshold defined for obs 118
# No default lower safe energy threshold defined for obs 118
# No default upper safe energy threshold defined for obs 119
# No default lower safe energy threshold defined for obs 119
# No default upper safe energy threshold defined for obs 12
# No default lower safe energy threshold defined for obs 12
# No default upper safe energy threshold defined for obs 120
# No default lower safe energy threshold defined for obs 120
# No default upper safe energy threshold defined for obs 121
# No default lower safe energy threshold defined for obs 121
# No default upper safe energy threshold defined for obs 122
# No default lower safe energy threshold defined for obs 122
# No default upper safe energy threshold defined for obs 123
# No default lower safe energy threshold defined for obs 123
# No default upper safe energy threshold defined for obs 124
# No default lower safe energy threshold defined for obs 124
# No default upper safe energy threshold defined for obs 125
# No default lower safe energy threshold defined for obs 125
# No default upper safe energy threshold defined for obs 126
# No default lower safe energy threshold defined for obs 126
# No default upper safe energy threshold defined for obs 127
# No default lower safe energy threshold defined for obs 127
# No default upper safe energy threshold defined for obs 128
# No default lower safe energy threshold defined for obs 128
# No default upper safe energy threshold defined for obs 129
# No default lower safe energy threshold defined for obs 129
# No default upper safe energy threshold defined for obs 13
# No default lower safe energy threshold defined for obs 13
# No default upper safe energy threshold defined for obs 130
# No default lower safe energy threshold defined for obs 130
# No default upper safe energy threshold defined for obs 131
# No default lower safe energy threshold defined for obs 131
# No default upper safe energy threshold defined for obs 132
# No default lower safe energy threshold defined for obs 132
# No default upper safe energy threshold defined for obs 133
# No default lower safe energy threshold defined for obs 133
# No default upper safe energy threshold defined for obs 134
# No default lower safe energy threshold defined for obs 134
# No default upper safe energy threshold defined for obs 135
# No default lower safe energy threshold defined for obs 135
# No default upper safe energy threshold defined for obs 136
# No default lower safe energy threshold defined for obs 136
# No default upper safe energy threshold defined for obs 137
# No default lower safe energy threshold defined for obs 137
# No default upper safe energy threshold defined for obs 138
# No default lower safe energy threshold defined for obs 138
# No default upper safe energy threshold defined for obs 139
# No default lower safe energy threshold defined for obs 139
# No default upper safe energy threshold defined for obs 14
# No default lower safe energy threshold defined for obs 14
# No default upper safe energy threshold defined for obs 140
# No default lower safe energy threshold defined for obs 140
# No default upper safe energy threshold defined for obs 141
# No default lower safe energy threshold defined for obs 141
# No default upper safe energy threshold defined for obs 142
# No default lower safe energy threshold defined for obs 142
# No default upper safe energy threshold defined for obs 143
# No default lower safe energy threshold defined for obs 143
# No default upper safe energy threshold defined for obs 144
# No default lower safe energy threshold defined for obs 144
# No default upper safe energy threshold defined for obs 145
# No default lower safe energy threshold defined for obs 145
# No default upper safe energy threshold defined for obs 146
# No default lower safe energy threshold defined for obs 146
# No default upper safe energy threshold defined for obs 147
# No default lower safe energy threshold defined for obs 147
# No default upper safe energy threshold defined for obs 148
# No default lower safe energy threshold defined for obs 148
# No default upper safe energy threshold defined for obs 149
# No default lower safe energy threshold defined for obs 149
# No default upper safe energy threshold defined for obs 15
# No default lower safe energy threshold defined for obs 15
# No default upper safe energy threshold defined for obs 150
# No default lower safe energy threshold defined for obs 150
# No default upper safe energy threshold defined for obs 151
# No default lower safe energy threshold defined for obs 151
# No default upper safe energy threshold defined for obs 152
# No default lower safe energy threshold defined for obs 152
# No default upper safe energy threshold defined for obs 153
# No default lower safe energy threshold defined for obs 153
# No default upper safe energy threshold defined for obs 154
# No default lower safe energy threshold defined for obs 154
# No default upper safe energy threshold defined for obs 155
# No default lower safe energy threshold defined for obs 155
# No default upper safe energy threshold defined for obs 156
# No default lower safe energy threshold defined for obs 156
# No default upper safe energy threshold defined for obs 157
# No default lower safe energy threshold defined for obs 157
# No default upper safe energy threshold defined for obs 158
# No default lower safe energy threshold defined for obs 158
# No default upper safe energy threshold defined for obs 159
# No default lower safe energy threshold defined for obs 159
# No default upper safe energy threshold defined for obs 16
# No default lower safe energy threshold defined for obs 16
# No default upper safe energy threshold defined for obs 160
# No default lower safe energy threshold defined for obs 160
# No default upper safe energy threshold defined for obs 161
# No default lower safe energy threshold defined for obs 161
# No default upper safe energy threshold defined for obs 162
# No default lower safe energy threshold defined for obs 162
# No default upper safe energy threshold defined for obs 163
# No default lower safe energy threshold defined for obs 163
# No default upper safe energy threshold defined for obs 164
# No default lower safe energy threshold defined for obs 164
# No default upper safe energy threshold defined for obs 165
# No default lower safe energy threshold defined for obs 165
# No default upper safe energy threshold defined for obs 166
# No default lower safe energy threshold defined for obs 166
# No default upper safe energy threshold defined for obs 167
# No default lower safe energy threshold defined for obs 167
# No default upper safe energy threshold defined for obs 168
# No default lower safe energy threshold defined for obs 168
# No default upper safe energy threshold defined for obs 169
# No default lower safe energy threshold defined for obs 169
# No default upper safe energy threshold defined for obs 17
# No default lower safe energy threshold defined for obs 17
# No default upper safe energy threshold defined for obs 170
# No default lower safe energy threshold defined for obs 170
# No default upper safe energy threshold defined for obs 171
# No default lower safe energy threshold defined for obs 171
# No default upper safe energy threshold defined for obs 172
# No default lower safe energy threshold defined for obs 172
# No default upper safe energy threshold defined for obs 173
# No default lower safe energy threshold defined for obs 173
# No default upper safe energy threshold defined for obs 174
# No default lower safe energy threshold defined for obs 174
# No default upper safe energy threshold defined for obs 175
# No default lower safe energy threshold defined for obs 175
# No default upper safe energy threshold defined for obs 176
# No default lower safe energy threshold defined for obs 176
# No default upper safe energy threshold defined for obs 177
# No default lower safe energy threshold defined for obs 177
# No default upper safe energy threshold defined for obs 178
# No default lower safe energy threshold defined for obs 178
# No default upper safe energy threshold defined for obs 179
# No default lower safe energy threshold defined for obs 179
# No default upper safe energy threshold defined for obs 18
# No default lower safe energy threshold defined for obs 18
# No default upper safe energy threshold defined for obs 180
# No default lower safe energy threshold defined for obs 180
# No default upper safe energy threshold defined for obs 181
# No default lower safe energy threshold defined for obs 181
# No default upper safe energy threshold defined for obs 182
# No default lower safe energy threshold defined for obs 182
# No default upper safe energy threshold defined for obs 183
# No default lower safe energy threshold defined for obs 183
# No default upper safe energy threshold defined for obs 184
# No default lower safe energy threshold defined for obs 184
# No default upper safe energy threshold defined for obs 185
# No default lower safe energy threshold defined for obs 185
# No default upper safe energy threshold defined for obs 186
# No default lower safe energy threshold defined for obs 186
# No default upper safe energy threshold defined for obs 187
# No default lower safe energy threshold defined for obs 187
# No default upper safe energy threshold defined for obs 188
# No default lower safe energy threshold defined for obs 188
# No default upper safe energy threshold defined for obs 189
# No default lower safe energy threshold defined for obs 189
# No default upper safe energy threshold defined for obs 19
# No default lower safe energy threshold defined for obs 19
# No default upper safe energy threshold defined for obs 190
# No default lower safe energy threshold defined for obs 190
# No default upper safe energy threshold defined for obs 191
# No default lower safe energy threshold defined for obs 191
# No default upper safe energy threshold defined for obs 192
# No default lower safe energy threshold defined for obs 192
# No default upper safe energy threshold defined for obs 193
# No default lower safe energy threshold defined for obs 193
# No default upper safe energy threshold defined for obs 194
# No default lower safe energy threshold defined for obs 194
# No default upper safe energy threshold defined for obs 195
# No default lower safe energy threshold defined for obs 195
# No default upper safe energy threshold defined for obs 196
# No default lower safe energy threshold defined for obs 196
# No default upper safe energy threshold defined for obs 197
# No default lower safe energy threshold defined for obs 197
# No default upper safe energy threshold defined for obs 198
# No default lower safe energy threshold defined for obs 198
# No default upper safe energy threshold defined for obs 199
# No default lower safe energy threshold defined for obs 199
# No default upper safe energy threshold defined for obs 2
# No default lower safe energy threshold defined for obs 2
# No default upper safe energy threshold defined for obs 20
# No default lower safe energy threshold defined for obs 20
# No default upper safe energy threshold defined for obs 200
# No default lower safe energy threshold defined for obs 200
# No default upper safe energy threshold defined for obs 201
# No default lower safe energy threshold defined for obs 201
# No default upper safe energy threshold defined for obs 202
# No default lower safe energy threshold defined for obs 202
# No default upper safe energy threshold defined for obs 203
# No default lower safe energy threshold defined for obs 203
# No default upper safe energy threshold defined for obs 204
# No default lower safe energy threshold defined for obs 204
# No default upper safe energy threshold defined for obs 205
# No default lower safe energy threshold defined for obs 205
# No default upper safe energy threshold defined for obs 206
# No default lower safe energy threshold defined for obs 206
# No default upper safe energy threshold defined for obs 207
# No default lower safe energy threshold defined for obs 207
# No default upper safe energy threshold defined for obs 208
# No default lower safe energy threshold defined for obs 208
# No default upper safe energy threshold defined for obs 209
# No default lower safe energy threshold defined for obs 209
# No default upper safe energy threshold defined for obs 21
# No default lower safe energy threshold defined for obs 21
# No default upper safe energy threshold defined for obs 210
# No default lower safe energy threshold defined for obs 210
# No default upper safe energy threshold defined for obs 211
# No default lower safe energy threshold defined for obs 211
# No default upper safe energy threshold defined for obs 212
# No default lower safe energy threshold defined for obs 212
# No default upper safe energy threshold defined for obs 213
# No default lower safe energy threshold defined for obs 213
# No default upper safe energy threshold defined for obs 214
# No default lower safe energy threshold defined for obs 214
# No default upper safe energy threshold defined for obs 215
# No default lower safe energy threshold defined for obs 215
# No default upper safe energy threshold defined for obs 216
# No default lower safe energy threshold defined for obs 216
# No default upper safe energy threshold defined for obs 217
# No default lower safe energy threshold defined for obs 217
# No default upper safe energy threshold defined for obs 218
# No default lower safe energy threshold defined for obs 218
# No default upper safe energy threshold defined for obs 219
# No default lower safe energy threshold defined for obs 219
# No default upper safe energy threshold defined for obs 22
# No default lower safe energy threshold defined for obs 22
# No default upper safe energy threshold defined for obs 220
# No default lower safe energy threshold defined for obs 220
# No default upper safe energy threshold defined for obs 221
# No default lower safe energy threshold defined for obs 221
# No default upper safe energy threshold defined for obs 222
# No default lower safe energy threshold defined for obs 222
# No default upper safe energy threshold defined for obs 223
# No default lower safe energy threshold defined for obs 223
# No default upper safe energy threshold defined for obs 224
# No default lower safe energy threshold defined for obs 224
# No default upper safe energy threshold defined for obs 225
# No default lower safe energy threshold defined for obs 225
# No default upper safe energy threshold defined for obs 226
# No default lower safe energy threshold defined for obs 226
# No default upper safe energy threshold defined for obs 227
# No default lower safe energy threshold defined for obs 227
# No default upper safe energy threshold defined for obs 228
# No default lower safe energy threshold defined for obs 228
# No default upper safe energy threshold defined for obs 229
# No default lower safe energy threshold defined for obs 229
# No default upper safe energy threshold defined for obs 23
# No default lower safe energy threshold defined for obs 23
# No default upper safe energy threshold defined for obs 230
# No default lower safe energy threshold defined for obs 230
# No default upper safe energy threshold defined for obs 231
# No default lower safe energy threshold defined for obs 231
# No default upper safe energy threshold defined for obs 232
# No default lower safe energy threshold defined for obs 232
# No default upper safe energy threshold defined for obs 233
# No default lower safe energy threshold defined for obs 233
# No default upper safe energy threshold defined for obs 234
# No default lower safe energy threshold defined for obs 234
# No default upper safe energy threshold defined for obs 235
# No default lower safe energy threshold defined for obs 235
# No default upper safe energy threshold defined for obs 236
# No default lower safe energy threshold defined for obs 236
# No default upper safe energy threshold defined for obs 237
# No default lower safe energy threshold defined for obs 237
# No default upper safe energy threshold defined for obs 238
# No default lower safe energy threshold defined for obs 238
# No default upper safe energy threshold defined for obs 239
# No default lower safe energy threshold defined for obs 239
# No default upper safe energy threshold defined for obs 24
# No default lower safe energy threshold defined for obs 24
# No default upper safe energy threshold defined for obs 240
# No default lower safe energy threshold defined for obs 240
# No default upper safe energy threshold defined for obs 241
# No default lower safe energy threshold defined for obs 241
# No default upper safe energy threshold defined for obs 242
# No default lower safe energy threshold defined for obs 242
# No default upper safe energy threshold defined for obs 243
# No default lower safe energy threshold defined for obs 243
# No default upper safe energy threshold defined for obs 244
# No default lower safe energy threshold defined for obs 244
# No default upper safe energy threshold defined for obs 245
# No default lower safe energy threshold defined for obs 245
# No default upper safe energy threshold defined for obs 246
# No default lower safe energy threshold defined for obs 246
# No default upper safe energy threshold defined for obs 247
# No default lower safe energy threshold defined for obs 247
# No default upper safe energy threshold defined for obs 25
# No default lower safe energy threshold defined for obs 25
# No default upper safe energy threshold defined for obs 26
# No default lower safe energy threshold defined for obs 26
# No default upper safe energy threshold defined for obs 27
# No default lower safe energy threshold defined for obs 27
# No default upper safe energy threshold defined for obs 28
# No default lower safe energy threshold defined for obs 28
# No default upper safe energy threshold defined for obs 29
# No default lower safe energy threshold defined for obs 29
# No default upper safe energy threshold defined for obs 3
# No default lower safe energy threshold defined for obs 3
# No default upper safe energy threshold defined for obs 30
# No default lower safe energy threshold defined for obs 30
# No default upper safe energy threshold defined for obs 31
# No default lower safe energy threshold defined for obs 31
# No default upper safe energy threshold defined for obs 32
# No default lower safe energy threshold defined for obs 32
# No default upper safe energy threshold defined for obs 33
# No default lower safe energy threshold defined for obs 33
# No default upper safe energy threshold defined for obs 34
# No default lower safe energy threshold defined for obs 34
# No default upper safe energy threshold defined for obs 35
# No default lower safe energy threshold defined for obs 35
# No default upper safe energy threshold defined for obs 36
# No default lower safe energy threshold defined for obs 36
# No default upper safe energy threshold defined for obs 37
# No default lower safe energy threshold defined for obs 37
# No default upper safe energy threshold defined for obs 38
# No default lower safe energy threshold defined for obs 38
# No default upper safe energy threshold defined for obs 39
# No default lower safe energy threshold defined for obs 39
# No default upper safe energy threshold defined for obs 4
# No default lower safe energy threshold defined for obs 4
# No default upper safe energy threshold defined for obs 40
# No default lower safe energy threshold defined for obs 40
# No default upper safe energy threshold defined for obs 41
# No default lower safe energy threshold defined for obs 41
# No default upper safe energy threshold defined for obs 42
# No default lower safe energy threshold defined for obs 42
# No default upper safe energy threshold defined for obs 43
# No default lower safe energy threshold defined for obs 43
# No default upper safe energy threshold defined for obs 44
# No default lower safe energy threshold defined for obs 44
# No default upper safe energy threshold defined for obs 45
# No default lower safe energy threshold defined for obs 45
# No default upper safe energy threshold defined for obs 46
# No default lower safe energy threshold defined for obs 46
# No default upper safe energy threshold defined for obs 47
# No default lower safe energy threshold defined for obs 47
# No default upper safe energy threshold defined for obs 48
# No default lower safe energy threshold defined for obs 48
# No default upper safe energy threshold defined for obs 49
# No default lower safe energy threshold defined for obs 49
# No default upper safe energy threshold defined for obs 5
# No default lower safe energy threshold defined for obs 5
# No default upper safe energy threshold defined for obs 50
# No default lower safe energy threshold defined for obs 50
# No default upper safe energy threshold defined for obs 51
# No default lower safe energy threshold defined for obs 51
# No default upper safe energy threshold defined for obs 52
# No default lower safe energy threshold defined for obs 52
# No default upper safe energy threshold defined for obs 53
# No default lower safe energy threshold defined for obs 53
# No default upper safe energy threshold defined for obs 54
# No default lower safe energy threshold defined for obs 54
# No default upper safe energy threshold defined for obs 55
# No default lower safe energy threshold defined for obs 55
# No default upper safe energy threshold defined for obs 56
# No default lower safe energy threshold defined for obs 56
# No default upper safe energy threshold defined for obs 57
# No default lower safe energy threshold defined for obs 57
# No default upper safe energy threshold defined for obs 58
# No default lower safe energy threshold defined for obs 58
# No default upper safe energy threshold defined for obs 59
# No default lower safe energy threshold defined for obs 59
# No default upper safe energy threshold defined for obs 6
# No default lower safe energy threshold defined for obs 6
# No default upper safe energy threshold defined for obs 60
# No default lower safe energy threshold defined for obs 60
# No default upper safe energy threshold defined for obs 61
# No default lower safe energy threshold defined for obs 61
# No default upper safe energy threshold defined for obs 62
# No default lower safe energy threshold defined for obs 62
# No default upper safe energy threshold defined for obs 63
# No default lower safe energy threshold defined for obs 63
# No default upper safe energy threshold defined for obs 64
# No default lower safe energy threshold defined for obs 64
# No default upper safe energy threshold defined for obs 65
# No default lower safe energy threshold defined for obs 65
# No default upper safe energy threshold defined for obs 66
# No default lower safe energy threshold defined for obs 66
# No default upper safe energy threshold defined for obs 67
# No default lower safe energy threshold defined for obs 67
# No default upper safe energy threshold defined for obs 68
# No default lower safe energy threshold defined for obs 68
# No default upper safe energy threshold defined for obs 69
# No default lower safe energy threshold defined for obs 69
# No default upper safe energy threshold defined for obs 7
# No default lower safe energy threshold defined for obs 7
# No default upper safe energy threshold defined for obs 70
# No default lower safe energy threshold defined for obs 70
# No default upper safe energy threshold defined for obs 71
# No default lower safe energy threshold defined for obs 71
# No default upper safe energy threshold defined for obs 72
# No default lower safe energy threshold defined for obs 72
# No default upper safe energy threshold defined for obs 73
# No default lower safe energy threshold defined for obs 73
# No default upper safe energy threshold defined for obs 74
# No default lower safe energy threshold defined for obs 74
# No default upper safe energy threshold defined for obs 75
# No default lower safe energy threshold defined for obs 75
# No default upper safe energy threshold defined for obs 76
# No default lower safe energy threshold defined for obs 76
# No default upper safe energy threshold defined for obs 77
# No default lower safe energy threshold defined for obs 77
# No default upper safe energy threshold defined for obs 78
# No default lower safe energy threshold defined for obs 78
# No default upper safe energy threshold defined for obs 79
# No default lower safe energy threshold defined for obs 79
# No default upper safe energy threshold defined for obs 8
# No default lower safe energy threshold defined for obs 8
# No default upper safe energy threshold defined for obs 80
# No default lower safe energy threshold defined for obs 80
# No default upper safe energy threshold defined for obs 81
# No default lower safe energy threshold defined for obs 81
# No default upper safe energy threshold defined for obs 82
# No default lower safe energy threshold defined for obs 82
# No default upper safe energy threshold defined for obs 83
# No default lower safe energy threshold defined for obs 83
# No default upper safe energy threshold defined for obs 84
# No default lower safe energy threshold defined for obs 84
# No default upper safe energy threshold defined for obs 85
# No default lower safe energy threshold defined for obs 85
# No default upper safe energy threshold defined for obs 86
# No default lower safe energy threshold defined for obs 86
# No default upper safe energy threshold defined for obs 87
# No default lower safe energy threshold defined for obs 87
# No default upper safe energy threshold defined for obs 88
# No default lower safe energy threshold defined for obs 88
# No default upper safe energy threshold defined for obs 89
# No default lower safe energy threshold defined for obs 89
# No default upper safe energy threshold defined for obs 9
# No default lower safe energy threshold defined for obs 9
# No default upper safe energy threshold defined for obs 90
# No default lower safe energy threshold defined for obs 90
# No default upper safe energy threshold defined for obs 91
# No default lower safe energy threshold defined for obs 91
# No default upper safe energy threshold defined for obs 92
# No default lower safe energy threshold defined for obs 92
# No default upper safe energy threshold defined for obs 93
# No default lower safe energy threshold defined for obs 93
# No default upper safe energy threshold defined for obs 94
# No default lower safe energy threshold defined for obs 94
# No default upper safe energy threshold defined for obs 95
# No default lower safe energy threshold defined for obs 95
# No default upper safe energy threshold defined for obs 96
# No default lower safe energy threshold defined for obs 96
# No default upper safe energy threshold defined for obs 97
# No default lower safe energy threshold defined for obs 97
# No default upper safe energy threshold defined for obs 98
# No default lower safe energy threshold defined for obs 98
# No default upper safe energy threshold defined for obs 99
# No default lower safe energy threshold defined for obs 99

# %%
# Plot the counts map overimposing the ON-OFF regions
ax = counts.smooth(0.05 * u.deg).plot(stretch="linear", cmap="viridis", add_cbar=True)
geom.plot_region(ax=ax, kwargs_point={"color": "k", "marker": "*"}, color="r", linewidth=2.5)
plot_spectrum_datasets_off_regions(ax=ax, datasets=datasets, linewidth=2.5)
plt.show()
# Out:
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/regions/shapes/circle.py:160: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   return Circle(xy=xy, radius=radius, **mpl_kwargs)

# %%
# We can also investigate the cumulative of all the runs:
info_table= datasets.info_table(cumulative=True)
info_table
# Out:
# <Table length=248>
#   name  counts       excess       ...   acceptance_off          alpha
#                                   ...
#   str7  int64       float64       ...      float64             float64
# ------- ------ ------------------ ... ------------------ -------------------
# stacked    225 14.666656494140625 ...               90.0  0.1666666716337204
# stacked    432   -0.6666259765625 ... 180.00001525878906  0.1666666567325592
# stacked    654   12.8333740234375 ...  270.0000305175781  0.1666666567325592
# stacked    879               27.5 ...              360.0  0.1666666716337204
# stacked   1086     12.16650390625 ... 449.99993896484375  0.1666666865348816
# stacked   1308   25.5001220703125 ...  540.0000610351562  0.1666666567325592
# stacked   1522    32.833251953125 ...              630.0  0.1666666716337204
# stacked   1747    47.499755859375 ...  719.9999389648438  0.1666666865348816
# stacked   1954   32.1663818359375 ...  809.9998779296875  0.1666666865348816
#     ...    ...                ... ...                ...                 ...
# stacked  52080      1204.98046875 ...      21599.9921875 0.16666673123836517
# stacked  52305        1219.640625 ...    21689.990234375 0.16666674613952637
# stacked  52512          1204.3125 ...      21779.9921875 0.16666673123836517
# stacked  52734      1217.82421875 ...     21869.99609375 0.16666670143604279
# stacked  52948      1225.15234375 ...    21959.994140625 0.16666671633720398
# stacked  53173          1239.8125 ...      22049.9921875 0.16666673123836517
# stacked  53380      1224.48828125 ...     22139.99609375 0.16666670143604279
# stacked  53602      1237.82421875 ...     22229.99609375 0.16666670143604279
# stacked  53816      1245.15234375 ...    22319.994140625 0.16666671633720398

# %%
# We can plot the excess and the significance
fig, (ax_excess, ax_sqrt_ts) = plt.subplots(figsize=(10, 4), ncols=2, nrows=1)
ax_excess.plot(
    info_table["livetime"].to("h"),
    info_table["excess"],
    marker="o",
    ls="none",
)

ax_excess.set_title("Excess")
ax_excess.set_xlabel("Livetime [h]")
ax_excess.set_ylabel("Excess events")

ax_sqrt_ts.plot(
    info_table["livetime"].to("h"),
    info_table["sqrt_ts"],
    marker="o",
    ls="none",
)

ax_sqrt_ts.set_title("Sqrt(TS)")
ax_sqrt_ts.set_xlabel("Livetime [h]")
ax_sqrt_ts.set_ylabel("Sqrt(TS)")
plt.show()

# %% [markdown]
# ## Extracting the Spectrum

# %% [markdown]
# We can perform a stacked analysis, i.e. all the datasets are stacked into a single dataset, where all the IRF properties are averaged. This is a reasonable choice as we do not expect so strong IRF property variations between the runs.

# %%
dataset_stacked = Datasets(datasets).stack_reduce()

# %% [markdown]
# ### Fitting

# %%
# Let's fit the data with a powerlaw model

spectral_model = PowerLawSpectralModel(
    amplitude = 1.1717e-13 * u.Unit("cm-2 s-1 TeV-1"),
    index = 2.6115,
    reference = 1 * u.TeV,
)

# Let's fit the data with a Exponential Cutoff Power Law Spectral Model

# spectral_model = ExpCutoffPowerLawSpectralModel(
#    amplitude =  1.5570e-13 * u.Unit("cm-2 s-1 TeV-1"),
#    index = 2.60 ,
#    lambda_ = 1.56  * u.Unit("TeV-1"),
#    reference = 1 * u.TeV,
# )

# spectral_model.amplitude.min = 1e-15
# spectral_model.amplitude.max = 1e-11
# spectral_model.index.min = 1
# spectral_model.index.max = 3.0
# spectral_model.lambda_.min = 0.001
# spectral_model.lambda_.max = 10.0

# spectral_model.index.frozen = True
# spectral_model.amplitude.frozen = True
# spectral_model.lambda_.frozen = True

# Let's fit the data with a Logarithmic Parabla Spectral Model
# spectral_model = LogParabolaSpectralModel(
#     amplitude = 1e-13 * u.Unit("cm-2 s-1 TeV-1"),
#     alpha = 2.5,
#     beta = 0.3,
#     reference = 1 * u.TeV
# )

# spectral_model.alpha.min = 1.0
# spectral_model.alpha.max = 4.0
# spectral_model.beta.min = 0.0
# spectral_model.beta.max = 2.0

# spectral_model = SmoothBrokenPowerLawSpectralModel(
#     amplitude = 1.0866e-12 * u.Unit("cm-2 s-1 TeV-1"),
#     index1 = 1.0000,
#     index2 = 5.0 ,
#     ebreak = 7.7 * u.TeV,
#     reference = 1.0 * u.TeV,
#     smoothing = 0.3,
# )

# spectral_model.index1.min = 1.0
# spectral_model.index1.max = 3.0
# spectral_model.index2.min = 2.0
# spectral_model.index2.max = 6.0
# spectral_model.ebreak.min = 0.1 
# spectral_model.ebreak.max = 10 

#spectral_model.ebreak.frozen = True
#spectral_model.index2.frozen = True

# Fitting original spectrum

# set an energy range for the spectral fit
# dataset_stacked.mask_fit = dataset_stacked.counts.geom.energy_mask(
#     energy_min=0.1 * u.TeV, energy_max=30 * u.TeV
# )

# powerlaw = PowerLawSpectralModel(
#     amplitude=6.49e-7 * u.Unit("cm-2 s-1 TeV-1"),
#     index=2.35,
#     reference=1.0485e-3 * u.TeV
# )


# ebl = EBLAbsorptionNormSpectralModel.read_builtin("dominguez", redshift=0.00379)

# spectral_model = powerlaw * ebl

# # Make a SkyModel object
# model = SkyModel(spectral_model=spectral_model, name="NGC_1068")

# Template spectral model. Defined by values from Ajello+ 2023
# data = ascii.read("/Users/tharacaba/Desktop/Tesis_2/MASS_Thesis/Simulation/Ajello_Starburst/Ajello_starburst.csv")

# # Getting the model in the correct units
# energy = data['x'] *u.GeV
# flux = data['y'] *u.GeV / (u.cm **2.0 * u.s)

# energy_MeV = energy.to(u.MeV)

# flux = flux.to(u.MeV / (u.cm ** 2.0 * u.s))
# flux_MeV = flux / energy_MeV**2  # divide by energy to get dN/dE

# template_spec_model = TemplateSpectralModel(energy=energy_MeV, values=flux_MeV)

model = SkyModel(spectral_model = spectral_model, name="NGC_1068")


# Associate the model to the dataset
dataset_stacked.models = model

fit = Fit(store_trace=True)
minuit_opts = {"tol": 0.001, "strategy": 2}
fit.backend = "minuit"
fit.optimize_opts = minuit_opts

result_stacked = fit.run(dataset_stacked)

print(result_stacked)
# Out:
# OptimizeResult
#
# 	backend    : minuit
# 	method     : migrad
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 88
# 	total stat : 754.17
#
# CovarianceResult
#
# 	backend    : minuit
# 	method     : hesse
# 	success    : True
# 	message    : Hesse terminated successfully.

# %%
print(result_stacked.minuit)
# Out:
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                                Migrad                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 754.2                      │              Nfcn = 88               │
# │ EDM = 2.87e-08 (Goal: 2e-06)     │                                      │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Valid Minimum           │   Below EDM threshold (goal x 10)    │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │      No parameters at limit      │           Below call limit           │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │             Hesse ok             │         Covariance accurate          │
# └──────────────────────────────────┴──────────────────────────────────────┘
# ┌───┬───────────────────┬───────────┬───────────┬────────────┬────────────┬─────────┬─────────┬───────┐
# │   │ Name              │   Value   │ Hesse Err │ Minos Err- │ Minos Err+ │ Limit-  │ Limit+  │ Fixed │
# ├───┼───────────────────┼───────────┼───────────┼────────────┼────────────┼─────────┼─────────┼───────┤
# │ 0 │ par_000_index     │   3.23    │   0.20    │            │            │         │         │       │
# │ 1 │ par_001_amplitude │   0.20    │   0.08    │            │            │         │         │       │
# └───┴───────────────────┴───────────┴───────────┴────────────┴────────────┴─────────┴─────────┴───────┘
# ┌───────────────────┬─────────────────────────────────────┐
# │                   │     par_000_index par_001_amplitude │
# ├───────────────────┼─────────────────────────────────────┤
# │     par_000_index │            0.0403            -0.014 │
# │ par_001_amplitude │            -0.014           0.00639 │
# └───────────────────┴─────────────────────────────────────┘

# %%
dataset_stacked.models.parameters.to_table()
# Out:
# <Table length=3>
# type    name     value         unit        error   ...   max   frozen link prior
# str1    str9    float64       str14       float64  ... float64  bool  str1  str1
# ---- --------- ---------- -------------- --------- ... ------- ------ ---- -----
#          index 3.2293e+00                2.006e-01 ...     nan  False
#      amplitude 2.0204e-14 TeV-1 s-1 cm-2 7.991e-15 ...     nan  False
#      reference 1.0000e+00            TeV 0.000e+00 ...     nan   True

# %% [markdown]
# ### Plotting the Spectrum

# %%
# I use the energy bins of the dataset. The `downsample` acts reducing the number of bins of a given integer.
energy_edges = energy_axis.downsample(1).edges 

# let's extract points for the `test_source` model. Errors will be at 1 sigma and upper limits at 3 sigma:
fpe = FluxPointsEstimator(
    energy_edges=energy_edges, source="NGC_1068", selection_optional="all", n_sigma=1, n_sigma_ul=3, n_jobs=7
)
flux_points = fpe.run(datasets=dataset_stacked)

flux_points.sqrt_ts_threshold_ul = 3

flux_points.to_table(sed_type="dnde", formatted=True)
# Out:
# <Table length=15>
#  e_ref   e_min   e_max        dnde      ...   counts   success   norm_scan
#   TeV     TeV     TeV   1 / (TeV s cm2) ...
# float64 float64 float64     float64     ... float64[1]   bool   float64[11]
# ------- ------- ------- --------------- ... ---------- ------- --------------
#   0.126   0.100   0.158       2.036e-11 ...    28086.0    True 0.200 .. 5.000
#   0.200   0.158   0.251      -3.552e-13 ...    13702.0    True 0.200 .. 5.000
#   0.316   0.251   0.398      -2.191e-12 ...     6076.0    True 0.200 .. 5.000
#   0.501   0.398   0.631       2.234e-12 ...     3286.0    True 0.200 .. 5.000
#   0.794   0.631   1.000       3.314e-13 ...     1612.0    True 0.200 .. 5.000
#   1.259   1.000   1.585      -8.648e-14 ...      434.0    True 0.200 .. 5.000
#   1.995   1.585   2.512      -1.691e-14 ...      248.0    True 0.200 .. 5.000
#   3.162   2.512   3.981      -1.071e-14 ...      124.0    True 0.200 .. 5.000
#   5.012   3.981   6.310      -2.791e-15 ...        0.0    True 0.200 .. 5.000
#   7.943   6.310  10.000      -3.039e-15 ...        0.0    True 0.200 .. 5.000
#  12.589  10.000  15.849       3.985e-15 ...      186.0    True 0.200 .. 5.000
#  19.953  15.849  25.119      -3.482e-16 ...        0.0    True 0.200 .. 5.000
#  31.623  25.119  39.811       4.718e-16 ...       62.0    True 0.200 .. 5.000
#  50.119  39.811  63.096      -1.452e-35 ...        0.0    True 0.200 .. 5.000
#  79.433  63.096 100.000      -3.282e-36 ...        0.0    True 0.200 .. 5.000

# %%
# Let's plot them, overlapping the significance
fig, ax = plt.subplots()
sed_type="e2dnde"
flux_points.plot(ax=ax, sed_type=sed_type, color="darkorange")
flux_points.plot_ts_profiles(ax=ax, sed_type=sed_type)
dataset_stacked.models[0].spectral_model.plot(ax=ax, energy_bounds=(e_min, e_max), sed_type=sed_type)
dataset_stacked.models[0].spectral_model.plot_error(ax=ax, energy_bounds=(e_min, e_max), sed_type=sed_type)
plt.show()

# %%
# Let's plot the best-fit model and the spectral points
fig, ax = plt.subplots()
sed_type="e2dnde"
flux_points.plot(ax=ax, sed_type=sed_type, color="red", label="Observed")
dataset_stacked.models[0].spectral_model.plot(ax=ax, energy_bounds=(e_min, e_max), sed_type=sed_type, color="green", label="Best-fit")
dataset_stacked.models[0].spectral_model.plot_error(ax=ax, energy_bounds=(e_min, e_max), sed_type=sed_type, facecolor="green")

plt.legend()

# %%
ax = dataset_original[0].spectral_model.plot(
    energy_bounds=[e_min, e_max] * u.TeV, 
    sed_type="e2dnde",
    label="Sim. model", 
    color='black'
    )

px = {"color": "red", "marker":"o"}
mx = {"color": "blue"}

# Fitting
# Quantify with the chi^2 statistic how well our parametric model of fit (that we made before) fits the spectral points
flux_points_dataset = FluxPointsDataset(data=flux_points, models=dataset_stacked.models[0])

flux_points_dataset.plot_spectrum(ax=ax, kwargs_fp=px, kwargs_model=mx)
#METHOD: Plot spectrum including flux points and model (defined in "flux_points_dataset")
#ax= axes to plot on; kwargs_fp= keywords for points; kwargs_model= keywords for model

ax.legend()
#ax.set_xlim(0.67,200)
#ax.set_ylim(2e-12,1e-10)

print(flux_points_dataset)
# Out:
# FluxPointsDataset
# -----------------
#
#   Name                            : Qljf6tL7
#
#   Number of total flux points     : 15
#   Number of fit bins              : 5
#
#   Fit statistic type              : chi2
#   Fit statistic value (-2 log(L)) : 309.05
#
#   Number of models                : 1
#   Number of parameters            : 3
#   Number of free parameters       : 2
#
#   Component 0: SkyModel
#
#     Name                      : NGC_1068
#     Datasets names            : None
#     Spectral model type       : PowerLawSpectralModel
#     Spatial  model type       :
#     Temporal model type       :
#     Parameters:
#       index                         :      3.229   +/-    0.20
#       amplitude                     :   2.02e-14   +/- 8.0e-15 1 / (TeV s cm2)
#       reference             (frozen):      1.000       TeV

# %%
flux_points_dataset.plot_fit()
# Out:
# (<Axes: xlabel='Energy [$\\mathrm{TeV}$]', ylabel='e2dnde [$\\mathrm{erg\\,s^{-1}\\,cm^{-2}}$]'>,
#  <Axes: xlabel='Energy [$\\mathrm{TeV}$]', ylabel='Residuals\n (data - model) / model'>)

# %%
import matplotlib.pyplot as plt
import glob, os, itertools
from pathlib import Path
import numpy as np
import pandas as pd
import astropy.units as u
from astropy.coordinates import Angle, SkyCoord
from astropy.time import Time
from astropy.table import Table
from gammapy.data import Observation, observatory_locations, EventList
from gammapy.datasets import MapDataset, MapDatasetEventSampler, FluxPointsDataset
from gammapy.estimators import ASmoothMapEstimator, TSMapEstimator, ExcessMapEstimator
from gammapy.estimators import FluxPointsEstimator
from gammapy.estimators.utils import resample_energy_edges
from gammapy.irf import load_irf_dict_from_file
from gammapy.makers import MapDatasetMaker, RingBackgroundMaker, SafeMaskMaker
from gammapy.datasets import MapDataset, MapDatasetOnOff
from gammapy.makers import MapDatasetMaker, WobbleRegionsFinder
from gammapy.maps import MapAxis, RegionNDMap, WcsGeom, Map, TimeMapAxis
from gammapy.modeling import Fit
from gammapy.modeling.models import (
    ConstantSpectralModel,
    FoVBackgroundModel,
    LightCurveTemplateTemporalModel,
    Models,
    PointSpatialModel,
    PowerLawSpectralModel,
    LogParabolaSpectralModel,
    SkyModel,
)
from regions import PointSkyRegion, CircleSkyRegion

from IPython.display import display
from gammapy.data import DataStore
from gammapy.datasets import (
    Datasets,
    FluxPointsDataset,
    SpectrumDataset,
    SpectrumDatasetOnOff,
)
from gammapy.estimators import FluxPointsEstimator
from gammapy.makers import (
    ReflectedRegionsBackgroundMaker,
    SafeMaskMaker,
    SpectrumDatasetMaker,
    FoVBackgroundMaker
)
from gammapy.maps import MapAxis, RegionGeom, WcsGeom
from gammapy.modeling import Fit
from gammapy.modeling.models import (
    ExpCutoffPowerLawSpectralModel,
    SkyModel,
    PiecewiseNormSpectralModel,
    PowerLawNormSpectralModel,
    LogParabolaSpectralModel,
)

import warnings
from gammapy.visualization import plot_spectrum_datasets_off_regions

# %%
# let's load the previously created Observation index files:
datastore = DataStore.from_dir("./")

observations = datastore.get_observations(obs_id=list(datastore.obs_table['OBS_ID']))

# we consider a square map of size 2.0 deg, spatially binned with bins of 0.02 deg;
# we define the ON region, assuming a circle of 0.2 deg of radius, for the source;
width = 2.0  #deg
binsz = 0.02 #deg
radius= 0.2  #deg

# let's define an exclusion region, in order to better estimate the bkg:
target_position = SkyCoord(40.669 * u.deg, -0.013 * u.deg, frame="icrs", unit="deg")
on_region_radius = Angle(radius * u.deg)
on_region = CircleSkyRegion(center=target_position, radius=on_region_radius)

npix = int(width/binsz)

exclusion_region = CircleSkyRegion(
    center=target_position,
    radius=radius * u.deg,
)

geom_excl = WcsGeom.create(
    npix=(npix, npix), binsz=binsz, skydir=target_position.galactic, proj="TAN", frame="galactic"
    #npix=(npix, npix), binsz=binsz, skydir=w1.galactic, proj="TAN", frame="galactic"
)

exclusion_mask = ~geom_excl.region_mask([exclusion_region])
exclusion_mask.plot()
plt.show()

# %%
# Create the reconstruced energy range:
e_min, e_max = 0.1 * u.TeV, 100 * u.TeV

energy_axis = MapAxis.from_energy_bounds(
    e_min, e_max, nbin=5, per_decade=True, unit="TeV", name="energy"
)

# Reduced IRFs are defined in true energy (i.e. not measured energy).
energy_axis_true = MapAxis.from_energy_bounds(
    0.01, 300, nbin=10, per_decade=True, unit="TeV", name="energy_true"
)

# geometry defining the ON region and SpectrumDataset based on it
geom = RegionGeom.create(region=on_region, axes=[energy_axis])

dataset_empty = SpectrumDataset.create(geom=geom, energy_axis_true=energy_axis_true)

dataset_maker = SpectrumDatasetMaker(
    containment_correction=True, selection=["counts", "exposure", "edisp"]
)

# tell the background maker to determine the reflected regions, excluding the source region:
maker_fov = ReflectedRegionsBackgroundMaker(exclusion_mask=exclusion_mask)

# let's impone a safe range for the analysis: we consider only events at a distance from the pointing direction < 1 deg.
offset_max = 2 * u.deg
safe_mask_masker = SafeMaskMaker(
    methods=["aeff-default","offset-max"], offset_max=offset_max
)

# create a counts map for visualisation later...
counts = Map.create(skydir=target_position, width=3)

# let's create the dataset for each observation and stack them all:
datasets = Datasets()

# let's loop over observations
for observation in observations:
    # generate a dataset object
    dataset = dataset_maker.run(
        dataset_empty.copy(name=str(observation.obs_id)), observation
    )
    # fill the dataset with the events of the observation
    counts.fill_events(observation.events)

    # calculate the bkg
    dataset_on_off = maker_fov.run(dataset, observation)
    # set a safe range for the analysis
    dataset_on_off = safe_mask_masker.run(dataset_on_off, observation)

    datasets.append(dataset_on_off)
# Out:
# No default upper safe energy threshold defined for obs 0
# No default lower safe energy threshold defined for obs 0
# No default upper safe energy threshold defined for obs 1
# No default lower safe energy threshold defined for obs 1
# No default upper safe energy threshold defined for obs 10
# No default lower safe energy threshold defined for obs 10
# No default upper safe energy threshold defined for obs 100
# No default lower safe energy threshold defined for obs 100
# No default upper safe energy threshold defined for obs 101
# No default lower safe energy threshold defined for obs 101
# No default upper safe energy threshold defined for obs 102
# No default lower safe energy threshold defined for obs 102
# No default upper safe energy threshold defined for obs 103
# No default lower safe energy threshold defined for obs 103
# No default upper safe energy threshold defined for obs 104
# No default lower safe energy threshold defined for obs 104
# No default upper safe energy threshold defined for obs 105
# No default lower safe energy threshold defined for obs 105
# No default upper safe energy threshold defined for obs 106
# No default lower safe energy threshold defined for obs 106
# No default upper safe energy threshold defined for obs 107
# No default lower safe energy threshold defined for obs 107
# No default upper safe energy threshold defined for obs 108
# No default lower safe energy threshold defined for obs 108
# No default upper safe energy threshold defined for obs 109
# No default lower safe energy threshold defined for obs 109
# No default upper safe energy threshold defined for obs 11
# No default lower safe energy threshold defined for obs 11
# No default upper safe energy threshold defined for obs 110
# No default lower safe energy threshold defined for obs 110
# No default upper safe energy threshold defined for obs 111
# No default lower safe energy threshold defined for obs 111
# No default upper safe energy threshold defined for obs 112
# No default lower safe energy threshold defined for obs 112
# No default upper safe energy threshold defined for obs 113
# No default lower safe energy threshold defined for obs 113
# No default upper safe energy threshold defined for obs 114
# No default lower safe energy threshold defined for obs 114
# No default upper safe energy threshold defined for obs 115
# No default lower safe energy threshold defined for obs 115
# No default upper safe energy threshold defined for obs 116
# No default lower safe energy threshold defined for obs 116
# No default upper safe energy threshold defined for obs 117
# No default lower safe energy threshold defined for obs 117
# No default upper safe energy threshold defined for obs 118
# No default lower safe energy threshold defined for obs 118
# No default upper safe energy threshold defined for obs 119
# No default lower safe energy threshold defined for obs 119
# No default upper safe energy threshold defined for obs 12
# No default lower safe energy threshold defined for obs 12
# No default upper safe energy threshold defined for obs 120
# No default lower safe energy threshold defined for obs 120
# No default upper safe energy threshold defined for obs 121
# No default lower safe energy threshold defined for obs 121
# No default upper safe energy threshold defined for obs 122
# No default lower safe energy threshold defined for obs 122
# No default upper safe energy threshold defined for obs 123
# No default lower safe energy threshold defined for obs 123
# No default upper safe energy threshold defined for obs 124
# No default lower safe energy threshold defined for obs 124
# No default upper safe energy threshold defined for obs 125
# No default lower safe energy threshold defined for obs 125
# No default upper safe energy threshold defined for obs 126
# No default lower safe energy threshold defined for obs 126
# No default upper safe energy threshold defined for obs 127
# No default lower safe energy threshold defined for obs 127
# No default upper safe energy threshold defined for obs 128
# No default lower safe energy threshold defined for obs 128
# No default upper safe energy threshold defined for obs 129
# No default lower safe energy threshold defined for obs 129
# No default upper safe energy threshold defined for obs 13
# No default lower safe energy threshold defined for obs 13
# No default upper safe energy threshold defined for obs 130
# No default lower safe energy threshold defined for obs 130
# No default upper safe energy threshold defined for obs 131
# No default lower safe energy threshold defined for obs 131
# No default upper safe energy threshold defined for obs 132
# No default lower safe energy threshold defined for obs 132
# No default upper safe energy threshold defined for obs 133
# No default lower safe energy threshold defined for obs 133
# No default upper safe energy threshold defined for obs 134
# No default lower safe energy threshold defined for obs 134
# No default upper safe energy threshold defined for obs 135
# No default lower safe energy threshold defined for obs 135
# No default upper safe energy threshold defined for obs 136
# No default lower safe energy threshold defined for obs 136
# No default upper safe energy threshold defined for obs 137
# No default lower safe energy threshold defined for obs 137
# No default upper safe energy threshold defined for obs 138
# No default lower safe energy threshold defined for obs 138
# No default upper safe energy threshold defined for obs 139
# No default lower safe energy threshold defined for obs 139
# No default upper safe energy threshold defined for obs 14
# No default lower safe energy threshold defined for obs 14
# No default upper safe energy threshold defined for obs 140
# No default lower safe energy threshold defined for obs 140
# No default upper safe energy threshold defined for obs 141
# No default lower safe energy threshold defined for obs 141
# No default upper safe energy threshold defined for obs 142
# No default lower safe energy threshold defined for obs 142
# No default upper safe energy threshold defined for obs 143
# No default lower safe energy threshold defined for obs 143
# No default upper safe energy threshold defined for obs 144
# No default lower safe energy threshold defined for obs 144
# No default upper safe energy threshold defined for obs 145
# No default lower safe energy threshold defined for obs 145
# No default upper safe energy threshold defined for obs 146
# No default lower safe energy threshold defined for obs 146
# No default upper safe energy threshold defined for obs 147
# No default lower safe energy threshold defined for obs 147
# No default upper safe energy threshold defined for obs 148
# No default lower safe energy threshold defined for obs 148
# No default upper safe energy threshold defined for obs 149
# No default lower safe energy threshold defined for obs 149
# No default upper safe energy threshold defined for obs 15
# No default lower safe energy threshold defined for obs 15
# No default upper safe energy threshold defined for obs 150
# No default lower safe energy threshold defined for obs 150
# No default upper safe energy threshold defined for obs 151
# No default lower safe energy threshold defined for obs 151
# No default upper safe energy threshold defined for obs 152
# No default lower safe energy threshold defined for obs 152
# No default upper safe energy threshold defined for obs 153
# No default lower safe energy threshold defined for obs 153
# No default upper safe energy threshold defined for obs 154
# No default lower safe energy threshold defined for obs 154
# No default upper safe energy threshold defined for obs 155
# No default lower safe energy threshold defined for obs 155
# No default upper safe energy threshold defined for obs 156
# No default lower safe energy threshold defined for obs 156
# No default upper safe energy threshold defined for obs 157
# No default lower safe energy threshold defined for obs 157
# No default upper safe energy threshold defined for obs 158
# No default lower safe energy threshold defined for obs 158
# No default upper safe energy threshold defined for obs 159
# No default lower safe energy threshold defined for obs 159
# No default upper safe energy threshold defined for obs 16
# No default lower safe energy threshold defined for obs 16
# No default upper safe energy threshold defined for obs 160
# No default lower safe energy threshold defined for obs 160
# No default upper safe energy threshold defined for obs 161
# No default lower safe energy threshold defined for obs 161
# No default upper safe energy threshold defined for obs 162
# No default lower safe energy threshold defined for obs 162
# No default upper safe energy threshold defined for obs 163
# No default lower safe energy threshold defined for obs 163
# No default upper safe energy threshold defined for obs 164
# No default lower safe energy threshold defined for obs 164
# No default upper safe energy threshold defined for obs 165
# No default lower safe energy threshold defined for obs 165
# No default upper safe energy threshold defined for obs 166
# No default lower safe energy threshold defined for obs 166
# No default upper safe energy threshold defined for obs 167
# No default lower safe energy threshold defined for obs 167
# No default upper safe energy threshold defined for obs 168
# No default lower safe energy threshold defined for obs 168
# No default upper safe energy threshold defined for obs 169
# No default lower safe energy threshold defined for obs 169
# No default upper safe energy threshold defined for obs 17
# No default lower safe energy threshold defined for obs 17
# No default upper safe energy threshold defined for obs 170
# No default lower safe energy threshold defined for obs 170
# No default upper safe energy threshold defined for obs 171
# No default lower safe energy threshold defined for obs 171
# No default upper safe energy threshold defined for obs 172
# No default lower safe energy threshold defined for obs 172
# No default upper safe energy threshold defined for obs 173
# No default lower safe energy threshold defined for obs 173
# No default upper safe energy threshold defined for obs 174
# No default lower safe energy threshold defined for obs 174
# No default upper safe energy threshold defined for obs 175
# No default lower safe energy threshold defined for obs 175
# No default upper safe energy threshold defined for obs 176
# No default lower safe energy threshold defined for obs 176
# No default upper safe energy threshold defined for obs 177
# No default lower safe energy threshold defined for obs 177
# No default upper safe energy threshold defined for obs 178
# No default lower safe energy threshold defined for obs 178
# No default upper safe energy threshold defined for obs 179
# No default lower safe energy threshold defined for obs 179
# No default upper safe energy threshold defined for obs 18
# No default lower safe energy threshold defined for obs 18
# No default upper safe energy threshold defined for obs 180
# No default lower safe energy threshold defined for obs 180
# No default upper safe energy threshold defined for obs 181
# No default lower safe energy threshold defined for obs 181
# No default upper safe energy threshold defined for obs 182
# No default lower safe energy threshold defined for obs 182
# No default upper safe energy threshold defined for obs 183
# No default lower safe energy threshold defined for obs 183
# No default upper safe energy threshold defined for obs 184
# No default lower safe energy threshold defined for obs 184
# No default upper safe energy threshold defined for obs 185
# No default lower safe energy threshold defined for obs 185
# No default upper safe energy threshold defined for obs 186
# No default lower safe energy threshold defined for obs 186
# No default upper safe energy threshold defined for obs 187
# No default lower safe energy threshold defined for obs 187
# No default upper safe energy threshold defined for obs 188
# No default lower safe energy threshold defined for obs 188
# No default upper safe energy threshold defined for obs 189
# No default lower safe energy threshold defined for obs 189
# No default upper safe energy threshold defined for obs 19
# No default lower safe energy threshold defined for obs 19
# No default upper safe energy threshold defined for obs 190
# No default lower safe energy threshold defined for obs 190
# No default upper safe energy threshold defined for obs 191
# No default lower safe energy threshold defined for obs 191
# No default upper safe energy threshold defined for obs 192
# No default lower safe energy threshold defined for obs 192
# No default upper safe energy threshold defined for obs 193
# No default lower safe energy threshold defined for obs 193
# No default upper safe energy threshold defined for obs 194
# No default lower safe energy threshold defined for obs 194
# No default upper safe energy threshold defined for obs 195
# No default lower safe energy threshold defined for obs 195
# No default upper safe energy threshold defined for obs 196
# No default lower safe energy threshold defined for obs 196
# No default upper safe energy threshold defined for obs 197
# No default lower safe energy threshold defined for obs 197
# No default upper safe energy threshold defined for obs 198
# No default lower safe energy threshold defined for obs 198
# No default upper safe energy threshold defined for obs 199
# No default lower safe energy threshold defined for obs 199
# No default upper safe energy threshold defined for obs 2
# No default lower safe energy threshold defined for obs 2
# No default upper safe energy threshold defined for obs 20
# No default lower safe energy threshold defined for obs 20
# No default upper safe energy threshold defined for obs 200
# No default lower safe energy threshold defined for obs 200
# No default upper safe energy threshold defined for obs 201
# No default lower safe energy threshold defined for obs 201
# No default upper safe energy threshold defined for obs 202
# No default lower safe energy threshold defined for obs 202
# No default upper safe energy threshold defined for obs 203
# No default lower safe energy threshold defined for obs 203
# No default upper safe energy threshold defined for obs 204
# No default lower safe energy threshold defined for obs 204
# No default upper safe energy threshold defined for obs 205
# No default lower safe energy threshold defined for obs 205
# No default upper safe energy threshold defined for obs 206
# No default lower safe energy threshold defined for obs 206
# No default upper safe energy threshold defined for obs 207
# No default lower safe energy threshold defined for obs 207
# No default upper safe energy threshold defined for obs 208
# No default lower safe energy threshold defined for obs 208
# No default upper safe energy threshold defined for obs 209
# No default lower safe energy threshold defined for obs 209
# No default upper safe energy threshold defined for obs 21
# No default lower safe energy threshold defined for obs 21
# No default upper safe energy threshold defined for obs 210
# No default lower safe energy threshold defined for obs 210
# No default upper safe energy threshold defined for obs 211
# No default lower safe energy threshold defined for obs 211
# No default upper safe energy threshold defined for obs 212
# No default lower safe energy threshold defined for obs 212
# No default upper safe energy threshold defined for obs 213
# No default lower safe energy threshold defined for obs 213
# No default upper safe energy threshold defined for obs 214
# No default lower safe energy threshold defined for obs 214
# No default upper safe energy threshold defined for obs 215
# No default lower safe energy threshold defined for obs 215
# No default upper safe energy threshold defined for obs 216
# No default lower safe energy threshold defined for obs 216
# No default upper safe energy threshold defined for obs 217
# No default lower safe energy threshold defined for obs 217
# No default upper safe energy threshold defined for obs 218
# No default lower safe energy threshold defined for obs 218
# No default upper safe energy threshold defined for obs 219
# No default lower safe energy threshold defined for obs 219
# No default upper safe energy threshold defined for obs 22
# No default lower safe energy threshold defined for obs 22
# No default upper safe energy threshold defined for obs 220
# No default lower safe energy threshold defined for obs 220
# No default upper safe energy threshold defined for obs 221
# No default lower safe energy threshold defined for obs 221
# No default upper safe energy threshold defined for obs 222
# No default lower safe energy threshold defined for obs 222
# No default upper safe energy threshold defined for obs 223
# No default lower safe energy threshold defined for obs 223
# No default upper safe energy threshold defined for obs 224
# No default lower safe energy threshold defined for obs 224
# No default upper safe energy threshold defined for obs 225
# No default lower safe energy threshold defined for obs 225
# No default upper safe energy threshold defined for obs 226
# No default lower safe energy threshold defined for obs 226
# No default upper safe energy threshold defined for obs 227
# No default lower safe energy threshold defined for obs 227
# No default upper safe energy threshold defined for obs 228
# No default lower safe energy threshold defined for obs 228
# No default upper safe energy threshold defined for obs 229
# No default lower safe energy threshold defined for obs 229
# No default upper safe energy threshold defined for obs 23
# No default lower safe energy threshold defined for obs 23
# No default upper safe energy threshold defined for obs 230
# No default lower safe energy threshold defined for obs 230
# No default upper safe energy threshold defined for obs 231
# No default lower safe energy threshold defined for obs 231
# No default upper safe energy threshold defined for obs 232
# No default lower safe energy threshold defined for obs 232
# No default upper safe energy threshold defined for obs 233
# No default lower safe energy threshold defined for obs 233
# No default upper safe energy threshold defined for obs 234
# No default lower safe energy threshold defined for obs 234
# No default upper safe energy threshold defined for obs 235
# No default lower safe energy threshold defined for obs 235
# No default upper safe energy threshold defined for obs 236
# No default lower safe energy threshold defined for obs 236
# No default upper safe energy threshold defined for obs 237
# No default lower safe energy threshold defined for obs 237
# No default upper safe energy threshold defined for obs 238
# No default lower safe energy threshold defined for obs 238
# No default upper safe energy threshold defined for obs 239
# No default lower safe energy threshold defined for obs 239
# No default upper safe energy threshold defined for obs 24
# No default lower safe energy threshold defined for obs 24
# No default upper safe energy threshold defined for obs 240
# No default lower safe energy threshold defined for obs 240
# No default upper safe energy threshold defined for obs 241
# No default lower safe energy threshold defined for obs 241
# No default upper safe energy threshold defined for obs 242
# No default lower safe energy threshold defined for obs 242
# No default upper safe energy threshold defined for obs 243
# No default lower safe energy threshold defined for obs 243
# No default upper safe energy threshold defined for obs 244
# No default lower safe energy threshold defined for obs 244
# No default upper safe energy threshold defined for obs 245
# No default lower safe energy threshold defined for obs 245
# No default upper safe energy threshold defined for obs 246
# No default lower safe energy threshold defined for obs 246
# No default upper safe energy threshold defined for obs 247
# No default lower safe energy threshold defined for obs 247
# No default upper safe energy threshold defined for obs 248
# No default lower safe energy threshold defined for obs 248
# No default upper safe energy threshold defined for obs 249
# No default lower safe energy threshold defined for obs 249
# No default upper safe energy threshold defined for obs 25
# No default lower safe energy threshold defined for obs 25
# No default upper safe energy threshold defined for obs 250
# No default lower safe energy threshold defined for obs 250
# No default upper safe energy threshold defined for obs 251
# No default lower safe energy threshold defined for obs 251
# No default upper safe energy threshold defined for obs 252
# No default lower safe energy threshold defined for obs 252
# No default upper safe energy threshold defined for obs 253
# No default lower safe energy threshold defined for obs 253
# No default upper safe energy threshold defined for obs 254
# No default lower safe energy threshold defined for obs 254
# No default upper safe energy threshold defined for obs 255
# No default lower safe energy threshold defined for obs 255
# No default upper safe energy threshold defined for obs 256
# No default lower safe energy threshold defined for obs 256
# No default upper safe energy threshold defined for obs 257
# No default lower safe energy threshold defined for obs 257
# No default upper safe energy threshold defined for obs 258
# No default lower safe energy threshold defined for obs 258
# No default upper safe energy threshold defined for obs 259
# No default lower safe energy threshold defined for obs 259
# No default upper safe energy threshold defined for obs 26
# No default lower safe energy threshold defined for obs 26
# No default upper safe energy threshold defined for obs 260
# No default lower safe energy threshold defined for obs 260
# No default upper safe energy threshold defined for obs 261
# No default lower safe energy threshold defined for obs 261
# No default upper safe energy threshold defined for obs 262
# No default lower safe energy threshold defined for obs 262
# No default upper safe energy threshold defined for obs 263
# No default lower safe energy threshold defined for obs 263
# No default upper safe energy threshold defined for obs 264
# No default lower safe energy threshold defined for obs 264
# No default upper safe energy threshold defined for obs 265
# No default lower safe energy threshold defined for obs 265
# No default upper safe energy threshold defined for obs 266
# No default lower safe energy threshold defined for obs 266
# No default upper safe energy threshold defined for obs 267
# No default lower safe energy threshold defined for obs 267
# No default upper safe energy threshold defined for obs 268
# No default lower safe energy threshold defined for obs 268
# No default upper safe energy threshold defined for obs 269
# No default lower safe energy threshold defined for obs 269
# No default upper safe energy threshold defined for obs 27
# No default lower safe energy threshold defined for obs 27
# No default upper safe energy threshold defined for obs 270
# No default lower safe energy threshold defined for obs 270
# No default upper safe energy threshold defined for obs 271
# No default lower safe energy threshold defined for obs 271
# No default upper safe energy threshold defined for obs 272
# No default lower safe energy threshold defined for obs 272
# No default upper safe energy threshold defined for obs 273
# No default lower safe energy threshold defined for obs 273
# No default upper safe energy threshold defined for obs 274
# No default lower safe energy threshold defined for obs 274
# No default upper safe energy threshold defined for obs 275
# No default lower safe energy threshold defined for obs 275
# No default upper safe energy threshold defined for obs 276
# No default lower safe energy threshold defined for obs 276
# No default upper safe energy threshold defined for obs 277
# No default lower safe energy threshold defined for obs 277
# No default upper safe energy threshold defined for obs 278
# No default lower safe energy threshold defined for obs 278
# No default upper safe energy threshold defined for obs 279
# No default lower safe energy threshold defined for obs 279
# No default upper safe energy threshold defined for obs 28
# No default lower safe energy threshold defined for obs 28
# No default upper safe energy threshold defined for obs 280
# No default lower safe energy threshold defined for obs 280
# No default upper safe energy threshold defined for obs 281
# No default lower safe energy threshold defined for obs 281
# No default upper safe energy threshold defined for obs 282
# No default lower safe energy threshold defined for obs 282
# No default upper safe energy threshold defined for obs 283
# No default lower safe energy threshold defined for obs 283
# No default upper safe energy threshold defined for obs 284
# No default lower safe energy threshold defined for obs 284
# No default upper safe energy threshold defined for obs 285
# No default lower safe energy threshold defined for obs 285
# No default upper safe energy threshold defined for obs 286
# No default lower safe energy threshold defined for obs 286
# No default upper safe energy threshold defined for obs 287
# No default lower safe energy threshold defined for obs 287
# No default upper safe energy threshold defined for obs 288
# No default lower safe energy threshold defined for obs 288
# No default upper safe energy threshold defined for obs 289
# No default lower safe energy threshold defined for obs 289
# No default upper safe energy threshold defined for obs 29
# No default lower safe energy threshold defined for obs 29
# No default upper safe energy threshold defined for obs 290
# No default lower safe energy threshold defined for obs 290
# No default upper safe energy threshold defined for obs 291
# No default lower safe energy threshold defined for obs 291
# No default upper safe energy threshold defined for obs 292
# No default lower safe energy threshold defined for obs 292
# No default upper safe energy threshold defined for obs 293
# No default lower safe energy threshold defined for obs 293
# No default upper safe energy threshold defined for obs 294
# No default lower safe energy threshold defined for obs 294
# No default upper safe energy threshold defined for obs 295
# No default lower safe energy threshold defined for obs 295
# No default upper safe energy threshold defined for obs 296
# No default lower safe energy threshold defined for obs 296
# No default upper safe energy threshold defined for obs 297
# No default lower safe energy threshold defined for obs 297
# No default upper safe energy threshold defined for obs 298
# No default lower safe energy threshold defined for obs 298
# No default upper safe energy threshold defined for obs 299
# No default lower safe energy threshold defined for obs 299
# No default upper safe energy threshold defined for obs 3
# No default lower safe energy threshold defined for obs 3
# No default upper safe energy threshold defined for obs 30
# No default lower safe energy threshold defined for obs 30
# No default upper safe energy threshold defined for obs 300
# No default lower safe energy threshold defined for obs 300
# No default upper safe energy threshold defined for obs 301
# No default lower safe energy threshold defined for obs 301
# No default upper safe energy threshold defined for obs 302
# No default lower safe energy threshold defined for obs 302
# No default upper safe energy threshold defined for obs 303
# No default lower safe energy threshold defined for obs 303
# No default upper safe energy threshold defined for obs 304
# No default lower safe energy threshold defined for obs 304
# No default upper safe energy threshold defined for obs 305
# No default lower safe energy threshold defined for obs 305
# No default upper safe energy threshold defined for obs 306
# No default lower safe energy threshold defined for obs 306
# No default upper safe energy threshold defined for obs 307
# No default lower safe energy threshold defined for obs 307
# No default upper safe energy threshold defined for obs 308
# No default lower safe energy threshold defined for obs 308
# No default upper safe energy threshold defined for obs 309
# No default lower safe energy threshold defined for obs 309
# No default upper safe energy threshold defined for obs 31
# No default lower safe energy threshold defined for obs 31
# No default upper safe energy threshold defined for obs 310
# No default lower safe energy threshold defined for obs 310
# No default upper safe energy threshold defined for obs 311
# No default lower safe energy threshold defined for obs 311
# No default upper safe energy threshold defined for obs 312
# No default lower safe energy threshold defined for obs 312
# No default upper safe energy threshold defined for obs 313
# No default lower safe energy threshold defined for obs 313
# No default upper safe energy threshold defined for obs 314
# No default lower safe energy threshold defined for obs 314
# No default upper safe energy threshold defined for obs 315
# No default lower safe energy threshold defined for obs 315
# No default upper safe energy threshold defined for obs 316
# No default lower safe energy threshold defined for obs 316
# No default upper safe energy threshold defined for obs 317
# No default lower safe energy threshold defined for obs 317
# No default upper safe energy threshold defined for obs 318
# No default lower safe energy threshold defined for obs 318
# No default upper safe energy threshold defined for obs 319
# No default lower safe energy threshold defined for obs 319
# No default upper safe energy threshold defined for obs 32
# No default lower safe energy threshold defined for obs 32
# No default upper safe energy threshold defined for obs 320
# No default lower safe energy threshold defined for obs 320
# No default upper safe energy threshold defined for obs 321
# No default lower safe energy threshold defined for obs 321
# No default upper safe energy threshold defined for obs 322
# No default lower safe energy threshold defined for obs 322
# No default upper safe energy threshold defined for obs 323
# No default lower safe energy threshold defined for obs 323
# No default upper safe energy threshold defined for obs 324
# No default lower safe energy threshold defined for obs 324
# No default upper safe energy threshold defined for obs 325
# No default lower safe energy threshold defined for obs 325
# No default upper safe energy threshold defined for obs 326
# No default lower safe energy threshold defined for obs 326
# No default upper safe energy threshold defined for obs 327
# No default lower safe energy threshold defined for obs 327
# No default upper safe energy threshold defined for obs 328
# No default lower safe energy threshold defined for obs 328
# No default upper safe energy threshold defined for obs 329
# No default lower safe energy threshold defined for obs 329
# No default upper safe energy threshold defined for obs 33
# No default lower safe energy threshold defined for obs 33
# No default upper safe energy threshold defined for obs 330
# No default lower safe energy threshold defined for obs 330
# No default upper safe energy threshold defined for obs 331
# No default lower safe energy threshold defined for obs 331
# No default upper safe energy threshold defined for obs 332
# No default lower safe energy threshold defined for obs 332
# No default upper safe energy threshold defined for obs 333
# No default lower safe energy threshold defined for obs 333
# No default upper safe energy threshold defined for obs 334
# No default lower safe energy threshold defined for obs 334
# No default upper safe energy threshold defined for obs 335
# No default lower safe energy threshold defined for obs 335
# No default upper safe energy threshold defined for obs 336
# No default lower safe energy threshold defined for obs 336
# No default upper safe energy threshold defined for obs 337
# No default lower safe energy threshold defined for obs 337
# No default upper safe energy threshold defined for obs 338
# No default lower safe energy threshold defined for obs 338
# No default upper safe energy threshold defined for obs 339
# No default lower safe energy threshold defined for obs 339
# No default upper safe energy threshold defined for obs 34
# No default lower safe energy threshold defined for obs 34
# No default upper safe energy threshold defined for obs 340
# No default lower safe energy threshold defined for obs 340
# No default upper safe energy threshold defined for obs 341
# No default lower safe energy threshold defined for obs 341
# No default upper safe energy threshold defined for obs 342
# No default lower safe energy threshold defined for obs 342
# No default upper safe energy threshold defined for obs 343
# No default lower safe energy threshold defined for obs 343
# No default upper safe energy threshold defined for obs 344
# No default lower safe energy threshold defined for obs 344
# No default upper safe energy threshold defined for obs 345
# No default lower safe energy threshold defined for obs 345
# No default upper safe energy threshold defined for obs 346
# No default lower safe energy threshold defined for obs 346
# No default upper safe energy threshold defined for obs 347
# No default lower safe energy threshold defined for obs 347
# No default upper safe energy threshold defined for obs 348
# No default lower safe energy threshold defined for obs 348
# No default upper safe energy threshold defined for obs 349
# No default lower safe energy threshold defined for obs 349
# No default upper safe energy threshold defined for obs 35
# No default lower safe energy threshold defined for obs 35
# No default upper safe energy threshold defined for obs 350
# No default lower safe energy threshold defined for obs 350
# No default upper safe energy threshold defined for obs 351
# No default lower safe energy threshold defined for obs 351
# No default upper safe energy threshold defined for obs 352
# No default lower safe energy threshold defined for obs 352
# No default upper safe energy threshold defined for obs 353
# No default lower safe energy threshold defined for obs 353
# No default upper safe energy threshold defined for obs 354
# No default lower safe energy threshold defined for obs 354
# No default upper safe energy threshold defined for obs 355
# No default lower safe energy threshold defined for obs 355
# No default upper safe energy threshold defined for obs 356
# No default lower safe energy threshold defined for obs 356
# No default upper safe energy threshold defined for obs 357
# No default lower safe energy threshold defined for obs 357
# No default upper safe energy threshold defined for obs 358
# No default lower safe energy threshold defined for obs 358
# No default upper safe energy threshold defined for obs 359
# No default lower safe energy threshold defined for obs 359
# No default upper safe energy threshold defined for obs 36
# No default lower safe energy threshold defined for obs 36
# No default upper safe energy threshold defined for obs 360
# No default lower safe energy threshold defined for obs 360
# No default upper safe energy threshold defined for obs 361
# No default lower safe energy threshold defined for obs 361
# No default upper safe energy threshold defined for obs 362
# No default lower safe energy threshold defined for obs 362
# No default upper safe energy threshold defined for obs 363
# No default lower safe energy threshold defined for obs 363
# No default upper safe energy threshold defined for obs 364
# No default lower safe energy threshold defined for obs 364
# No default upper safe energy threshold defined for obs 365
# No default lower safe energy threshold defined for obs 365
# No default upper safe energy threshold defined for obs 366
# No default lower safe energy threshold defined for obs 366
# No default upper safe energy threshold defined for obs 367
# No default lower safe energy threshold defined for obs 367
# No default upper safe energy threshold defined for obs 368
# No default lower safe energy threshold defined for obs 368
# No default upper safe energy threshold defined for obs 369
# No default lower safe energy threshold defined for obs 369
# No default upper safe energy threshold defined for obs 37
# No default lower safe energy threshold defined for obs 37
# No default upper safe energy threshold defined for obs 370
# No default lower safe energy threshold defined for obs 370
# No default upper safe energy threshold defined for obs 371
# No default lower safe energy threshold defined for obs 371
# No default upper safe energy threshold defined for obs 372
# No default lower safe energy threshold defined for obs 372
# No default upper safe energy threshold defined for obs 373
# No default lower safe energy threshold defined for obs 373
# No default upper safe energy threshold defined for obs 374
# No default lower safe energy threshold defined for obs 374
# No default upper safe energy threshold defined for obs 375
# No default lower safe energy threshold defined for obs 375
# No default upper safe energy threshold defined for obs 376
# No default lower safe energy threshold defined for obs 376
# No default upper safe energy threshold defined for obs 377
# No default lower safe energy threshold defined for obs 377
# No default upper safe energy threshold defined for obs 378
# No default lower safe energy threshold defined for obs 378
# No default upper safe energy threshold defined for obs 379
# No default lower safe energy threshold defined for obs 379
# No default upper safe energy threshold defined for obs 38
# No default lower safe energy threshold defined for obs 38
# No default upper safe energy threshold defined for obs 380
# No default lower safe energy threshold defined for obs 380
# No default upper safe energy threshold defined for obs 381
# No default lower safe energy threshold defined for obs 381
# No default upper safe energy threshold defined for obs 382
# No default lower safe energy threshold defined for obs 382
# No default upper safe energy threshold defined for obs 383
# No default lower safe energy threshold defined for obs 383
# No default upper safe energy threshold defined for obs 384
# No default lower safe energy threshold defined for obs 384
# No default upper safe energy threshold defined for obs 385
# No default lower safe energy threshold defined for obs 385
# No default upper safe energy threshold defined for obs 386
# No default lower safe energy threshold defined for obs 386
# No default upper safe energy threshold defined for obs 387
# No default lower safe energy threshold defined for obs 387
# No default upper safe energy threshold defined for obs 388
# No default lower safe energy threshold defined for obs 388
# No default upper safe energy threshold defined for obs 389
# No default lower safe energy threshold defined for obs 389
# No default upper safe energy threshold defined for obs 39
# No default lower safe energy threshold defined for obs 39
# No default upper safe energy threshold defined for obs 390
# No default lower safe energy threshold defined for obs 390
# No default upper safe energy threshold defined for obs 391
# No default lower safe energy threshold defined for obs 391
# No default upper safe energy threshold defined for obs 392
# No default lower safe energy threshold defined for obs 392
# No default upper safe energy threshold defined for obs 393
# No default lower safe energy threshold defined for obs 393
# No default upper safe energy threshold defined for obs 394
# No default lower safe energy threshold defined for obs 394
# No default upper safe energy threshold defined for obs 395
# No default lower safe energy threshold defined for obs 395
# No default upper safe energy threshold defined for obs 396
# No default lower safe energy threshold defined for obs 396
# No default upper safe energy threshold defined for obs 397
# No default lower safe energy threshold defined for obs 397
# No default upper safe energy threshold defined for obs 398
# No default lower safe energy threshold defined for obs 398
# No default upper safe energy threshold defined for obs 399
# No default lower safe energy threshold defined for obs 399
# No default upper safe energy threshold defined for obs 4
# No default lower safe energy threshold defined for obs 4
# No default upper safe energy threshold defined for obs 40
# No default lower safe energy threshold defined for obs 40
# No default upper safe energy threshold defined for obs 400
# No default lower safe energy threshold defined for obs 400
# No default upper safe energy threshold defined for obs 401
# No default lower safe energy threshold defined for obs 401
# No default upper safe energy threshold defined for obs 402
# No default lower safe energy threshold defined for obs 402
# No default upper safe energy threshold defined for obs 403
# No default lower safe energy threshold defined for obs 403
# No default upper safe energy threshold defined for obs 404
# No default lower safe energy threshold defined for obs 404
# No default upper safe energy threshold defined for obs 405
# No default lower safe energy threshold defined for obs 405
# No default upper safe energy threshold defined for obs 406
# No default lower safe energy threshold defined for obs 406
# No default upper safe energy threshold defined for obs 407
# No default lower safe energy threshold defined for obs 407
# No default upper safe energy threshold defined for obs 408
# No default lower safe energy threshold defined for obs 408
# No default upper safe energy threshold defined for obs 409
# No default lower safe energy threshold defined for obs 409
# No default upper safe energy threshold defined for obs 41
# No default lower safe energy threshold defined for obs 41
# No default upper safe energy threshold defined for obs 410
# No default lower safe energy threshold defined for obs 410
# No default upper safe energy threshold defined for obs 411
# No default lower safe energy threshold defined for obs 411
# No default upper safe energy threshold defined for obs 412
# No default lower safe energy threshold defined for obs 412
# No default upper safe energy threshold defined for obs 413
# No default lower safe energy threshold defined for obs 413
# No default upper safe energy threshold defined for obs 414
# No default lower safe energy threshold defined for obs 414
# No default upper safe energy threshold defined for obs 415
# No default lower safe energy threshold defined for obs 415
# No default upper safe energy threshold defined for obs 416
# No default lower safe energy threshold defined for obs 416
# No default upper safe energy threshold defined for obs 417
# No default lower safe energy threshold defined for obs 417
# No default upper safe energy threshold defined for obs 418
# No default lower safe energy threshold defined for obs 418
# No default upper safe energy threshold defined for obs 419
# No default lower safe energy threshold defined for obs 419
# No default upper safe energy threshold defined for obs 42
# No default lower safe energy threshold defined for obs 42
# No default upper safe energy threshold defined for obs 420
# No default lower safe energy threshold defined for obs 420
# No default upper safe energy threshold defined for obs 421
# No default lower safe energy threshold defined for obs 421
# No default upper safe energy threshold defined for obs 422
# No default lower safe energy threshold defined for obs 422
# No default upper safe energy threshold defined for obs 423
# No default lower safe energy threshold defined for obs 423
# No default upper safe energy threshold defined for obs 424
# No default lower safe energy threshold defined for obs 424
# No default upper safe energy threshold defined for obs 425
# No default lower safe energy threshold defined for obs 425
# No default upper safe energy threshold defined for obs 426
# No default lower safe energy threshold defined for obs 426
# No default upper safe energy threshold defined for obs 427
# No default lower safe energy threshold defined for obs 427
# No default upper safe energy threshold defined for obs 428
# No default lower safe energy threshold defined for obs 428
# No default upper safe energy threshold defined for obs 429
# No default lower safe energy threshold defined for obs 429
# No default upper safe energy threshold defined for obs 43
# No default lower safe energy threshold defined for obs 43
# No default upper safe energy threshold defined for obs 430
# No default lower safe energy threshold defined for obs 430
# No default upper safe energy threshold defined for obs 431
# No default lower safe energy threshold defined for obs 431
# No default upper safe energy threshold defined for obs 432
# No default lower safe energy threshold defined for obs 432
# No default upper safe energy threshold defined for obs 433
# No default lower safe energy threshold defined for obs 433
# No default upper safe energy threshold defined for obs 434
# No default lower safe energy threshold defined for obs 434
# No default upper safe energy threshold defined for obs 435
# No default lower safe energy threshold defined for obs 435
# No default upper safe energy threshold defined for obs 436
# No default lower safe energy threshold defined for obs 436
# No default upper safe energy threshold defined for obs 437
# No default lower safe energy threshold defined for obs 437
# No default upper safe energy threshold defined for obs 438
# No default lower safe energy threshold defined for obs 438
# No default upper safe energy threshold defined for obs 439
# No default lower safe energy threshold defined for obs 439
# No default upper safe energy threshold defined for obs 44
# No default lower safe energy threshold defined for obs 44
# No default upper safe energy threshold defined for obs 440
# No default lower safe energy threshold defined for obs 440
# No default upper safe energy threshold defined for obs 441
# No default lower safe energy threshold defined for obs 441
# No default upper safe energy threshold defined for obs 442
# No default lower safe energy threshold defined for obs 442
# No default upper safe energy threshold defined for obs 443
# No default lower safe energy threshold defined for obs 443
# No default upper safe energy threshold defined for obs 444
# No default lower safe energy threshold defined for obs 444
# No default upper safe energy threshold defined for obs 445
# No default lower safe energy threshold defined for obs 445
# No default upper safe energy threshold defined for obs 446
# No default lower safe energy threshold defined for obs 446
# No default upper safe energy threshold defined for obs 447
# No default lower safe energy threshold defined for obs 447
# No default upper safe energy threshold defined for obs 448
# No default lower safe energy threshold defined for obs 448
# No default upper safe energy threshold defined for obs 449
# No default lower safe energy threshold defined for obs 449
# No default upper safe energy threshold defined for obs 45
# No default lower safe energy threshold defined for obs 45
# No default upper safe energy threshold defined for obs 450
# No default lower safe energy threshold defined for obs 450
# No default upper safe energy threshold defined for obs 451
# No default lower safe energy threshold defined for obs 451
# No default upper safe energy threshold defined for obs 452
# No default lower safe energy threshold defined for obs 452
# No default upper safe energy threshold defined for obs 453
# No default lower safe energy threshold defined for obs 453
# No default upper safe energy threshold defined for obs 454
# No default lower safe energy threshold defined for obs 454
# No default upper safe energy threshold defined for obs 455
# No default lower safe energy threshold defined for obs 455
# No default upper safe energy threshold defined for obs 456
# No default lower safe energy threshold defined for obs 456
# No default upper safe energy threshold defined for obs 457
# No default lower safe energy threshold defined for obs 457
# No default upper safe energy threshold defined for obs 458
# No default lower safe energy threshold defined for obs 458
# No default upper safe energy threshold defined for obs 459
# No default lower safe energy threshold defined for obs 459
# No default upper safe energy threshold defined for obs 46
# No default lower safe energy threshold defined for obs 46
# No default upper safe energy threshold defined for obs 460
# No default lower safe energy threshold defined for obs 460
# No default upper safe energy threshold defined for obs 461
# No default lower safe energy threshold defined for obs 461
# No default upper safe energy threshold defined for obs 462
# No default lower safe energy threshold defined for obs 462
# No default upper safe energy threshold defined for obs 463
# No default lower safe energy threshold defined for obs 463
# No default upper safe energy threshold defined for obs 464
# No default lower safe energy threshold defined for obs 464
# No default upper safe energy threshold defined for obs 465
# No default lower safe energy threshold defined for obs 465
# No default upper safe energy threshold defined for obs 466
# No default lower safe energy threshold defined for obs 466
# No default upper safe energy threshold defined for obs 467
# No default lower safe energy threshold defined for obs 467
# No default upper safe energy threshold defined for obs 468
# No default lower safe energy threshold defined for obs 468
# No default upper safe energy threshold defined for obs 469
# No default lower safe energy threshold defined for obs 469
# No default upper safe energy threshold defined for obs 47
# No default lower safe energy threshold defined for obs 47
# No default upper safe energy threshold defined for obs 470
# No default lower safe energy threshold defined for obs 470
# No default upper safe energy threshold defined for obs 471
# No default lower safe energy threshold defined for obs 471
# No default upper safe energy threshold defined for obs 472
# No default lower safe energy threshold defined for obs 472
# No default upper safe energy threshold defined for obs 473
# No default lower safe energy threshold defined for obs 473
# No default upper safe energy threshold defined for obs 474
# No default lower safe energy threshold defined for obs 474
# No default upper safe energy threshold defined for obs 475
# No default lower safe energy threshold defined for obs 475
# No default upper safe energy threshold defined for obs 476
# No default lower safe energy threshold defined for obs 476
# No default upper safe energy threshold defined for obs 477
# No default lower safe energy threshold defined for obs 477
# No default upper safe energy threshold defined for obs 478
# No default lower safe energy threshold defined for obs 478
# No default upper safe energy threshold defined for obs 479
# No default lower safe energy threshold defined for obs 479
# No default upper safe energy threshold defined for obs 48
# No default lower safe energy threshold defined for obs 48
# No default upper safe energy threshold defined for obs 480
# No default lower safe energy threshold defined for obs 480
# No default upper safe energy threshold defined for obs 481
# No default lower safe energy threshold defined for obs 481
# No default upper safe energy threshold defined for obs 482
# No default lower safe energy threshold defined for obs 482
# No default upper safe energy threshold defined for obs 483
# No default lower safe energy threshold defined for obs 483
# No default upper safe energy threshold defined for obs 484
# No default lower safe energy threshold defined for obs 484
# No default upper safe energy threshold defined for obs 485
# No default lower safe energy threshold defined for obs 485
# No default upper safe energy threshold defined for obs 486
# No default lower safe energy threshold defined for obs 486
# No default upper safe energy threshold defined for obs 487
# No default lower safe energy threshold defined for obs 487
# No default upper safe energy threshold defined for obs 488
# No default lower safe energy threshold defined for obs 488
# No default upper safe energy threshold defined for obs 489
# No default lower safe energy threshold defined for obs 489
# No default upper safe energy threshold defined for obs 49
# No default lower safe energy threshold defined for obs 49
# No default upper safe energy threshold defined for obs 490
# No default lower safe energy threshold defined for obs 490
# No default upper safe energy threshold defined for obs 491
# No default lower safe energy threshold defined for obs 491
# No default upper safe energy threshold defined for obs 492
# No default lower safe energy threshold defined for obs 492
# No default upper safe energy threshold defined for obs 493
# No default lower safe energy threshold defined for obs 493
# No default upper safe energy threshold defined for obs 494
# No default lower safe energy threshold defined for obs 494
# No default upper safe energy threshold defined for obs 495
# No default lower safe energy threshold defined for obs 495
# No default upper safe energy threshold defined for obs 496
# No default lower safe energy threshold defined for obs 496
# No default upper safe energy threshold defined for obs 497
# No default lower safe energy threshold defined for obs 497
# No default upper safe energy threshold defined for obs 498
# No default lower safe energy threshold defined for obs 498
# No default upper safe energy threshold defined for obs 499
# No default lower safe energy threshold defined for obs 499
# No default upper safe energy threshold defined for obs 5
# No default lower safe energy threshold defined for obs 5
# No default upper safe energy threshold defined for obs 50
# No default lower safe energy threshold defined for obs 50
# No default upper safe energy threshold defined for obs 51
# No default lower safe energy threshold defined for obs 51
# No default upper safe energy threshold defined for obs 52
# No default lower safe energy threshold defined for obs 52
# No default upper safe energy threshold defined for obs 53
# No default lower safe energy threshold defined for obs 53
# No default upper safe energy threshold defined for obs 54
# No default lower safe energy threshold defined for obs 54
# No default upper safe energy threshold defined for obs 55
# No default lower safe energy threshold defined for obs 55
# No default upper safe energy threshold defined for obs 56
# No default lower safe energy threshold defined for obs 56
# No default upper safe energy threshold defined for obs 57
# No default lower safe energy threshold defined for obs 57
# No default upper safe energy threshold defined for obs 58
# No default lower safe energy threshold defined for obs 58
# No default upper safe energy threshold defined for obs 59
# No default lower safe energy threshold defined for obs 59
# No default upper safe energy threshold defined for obs 6
# No default lower safe energy threshold defined for obs 6
# No default upper safe energy threshold defined for obs 60
# No default lower safe energy threshold defined for obs 60
# No default upper safe energy threshold defined for obs 61
# No default lower safe energy threshold defined for obs 61
# No default upper safe energy threshold defined for obs 62
# No default lower safe energy threshold defined for obs 62
# No default upper safe energy threshold defined for obs 63
# No default lower safe energy threshold defined for obs 63
# No default upper safe energy threshold defined for obs 64
# No default lower safe energy threshold defined for obs 64
# No default upper safe energy threshold defined for obs 65
# No default lower safe energy threshold defined for obs 65
# No default upper safe energy threshold defined for obs 66
# No default lower safe energy threshold defined for obs 66
# No default upper safe energy threshold defined for obs 67
# No default lower safe energy threshold defined for obs 67
# No default upper safe energy threshold defined for obs 68
# No default lower safe energy threshold defined for obs 68
# No default upper safe energy threshold defined for obs 69
# No default lower safe energy threshold defined for obs 69
# No default upper safe energy threshold defined for obs 7
# No default lower safe energy threshold defined for obs 7
# No default upper safe energy threshold defined for obs 70
# No default lower safe energy threshold defined for obs 70
# No default upper safe energy threshold defined for obs 71
# No default lower safe energy threshold defined for obs 71
# No default upper safe energy threshold defined for obs 72
# No default lower safe energy threshold defined for obs 72
# No default upper safe energy threshold defined for obs 73
# No default lower safe energy threshold defined for obs 73
# No default upper safe energy threshold defined for obs 74
# No default lower safe energy threshold defined for obs 74
# No default upper safe energy threshold defined for obs 75
# No default lower safe energy threshold defined for obs 75
# No default upper safe energy threshold defined for obs 76
# No default lower safe energy threshold defined for obs 76
# No default upper safe energy threshold defined for obs 77
# No default lower safe energy threshold defined for obs 77
# No default upper safe energy threshold defined for obs 78
# No default lower safe energy threshold defined for obs 78
# No default upper safe energy threshold defined for obs 79
# No default lower safe energy threshold defined for obs 79
# No default upper safe energy threshold defined for obs 8
# No default lower safe energy threshold defined for obs 8
# No default upper safe energy threshold defined for obs 80
# No default lower safe energy threshold defined for obs 80
# No default upper safe energy threshold defined for obs 81
# No default lower safe energy threshold defined for obs 81
# No default upper safe energy threshold defined for obs 82
# No default lower safe energy threshold defined for obs 82
# No default upper safe energy threshold defined for obs 83
# No default lower safe energy threshold defined for obs 83
# No default upper safe energy threshold defined for obs 84
# No default lower safe energy threshold defined for obs 84
# No default upper safe energy threshold defined for obs 85
# No default lower safe energy threshold defined for obs 85
# No default upper safe energy threshold defined for obs 86
# No default lower safe energy threshold defined for obs 86
# No default upper safe energy threshold defined for obs 87
# No default lower safe energy threshold defined for obs 87
# No default upper safe energy threshold defined for obs 88
# No default lower safe energy threshold defined for obs 88
# No default upper safe energy threshold defined for obs 89
# No default lower safe energy threshold defined for obs 89
# No default upper safe energy threshold defined for obs 9
# No default lower safe energy threshold defined for obs 9
# No default upper safe energy threshold defined for obs 90
# No default lower safe energy threshold defined for obs 90
# No default upper safe energy threshold defined for obs 91
# No default lower safe energy threshold defined for obs 91
# No default upper safe energy threshold defined for obs 92
# No default lower safe energy threshold defined for obs 92
# No default upper safe energy threshold defined for obs 93
# No default lower safe energy threshold defined for obs 93
# No default upper safe energy threshold defined for obs 94
# No default lower safe energy threshold defined for obs 94
# No default upper safe energy threshold defined for obs 95
# No default lower safe energy threshold defined for obs 95
# No default upper safe energy threshold defined for obs 96
# No default lower safe energy threshold defined for obs 96
# No default upper safe energy threshold defined for obs 97
# No default lower safe energy threshold defined for obs 97
# No default upper safe energy threshold defined for obs 98
# No default lower safe energy threshold defined for obs 98
# No default upper safe energy threshold defined for obs 99
# No default lower safe energy threshold defined for obs 99

# %%
#plot the counts map overimposing the ON-OFF regions
ax = counts.smooth(0.05 * u.deg).plot(stretch="linear", cmap="viridis", add_cbar=True)
geom.plot_region(ax=ax, kwargs_point={"color": "k", "marker": "*"}, color="r", linewidth=2.5)
plot_spectrum_datasets_off_regions(ax=ax, datasets=datasets, linewidth=2.5)
plt.show()
# Out:
# /Users/tharacaba/miniconda3/envs/gammapy-1.3/lib/python3.11/site-packages/regions/shapes/circle.py:160: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   return Circle(xy=xy, radius=radius, **mpl_kwargs)

# %%
# Individual
info_table=datasets.info_table()
info_table
# Out:
# <Table length=500>
# name counts        excess       ...   acceptance_off         alpha
#                                 ...
# str3 int64        float64       ...      float64            float64
# ---- ------ ------------------- ... ----------------- -------------------
#    0    225  14.666666666666686 ...              90.0 0.16666666666666666
#    1    233   4.833333333333371 ... 90.00000000000001 0.16666666666666663
#   10    196 -22.999999999999915 ... 90.00000000000003  0.1666666666666666
#  100    227   9.166666666666686 ...              90.0 0.16666666666666666
#  101    234                13.5 ...              90.0 0.16666666666666666
#  102    219                -1.5 ...              90.0 0.16666666666666666
#  103    221                10.0 ...              90.0 0.16666666666666666
#  104    207 -2.8333333333333144 ...              90.0 0.16666666666666666
#  105    208                -6.5 ...              90.0 0.16666666666666666
#  ...    ...                 ... ...               ...                 ...
#   91    237  10.333333333333371 ... 90.00000000000001 0.16666666666666663
#   92    226  14.166666666666686 ...              90.0 0.16666666666666666
#   93    233                19.0 ...              90.0 0.16666666666666666
#   94    191 -22.499999999999943 ... 90.00000000000001 0.16666666666666663
#   95    197               -28.0 ...              90.0 0.16666666666666666
#   96    215     9.3333333333334 ... 90.00000000000003  0.1666666666666666
#   97    207               -10.5 ...              90.0 0.16666666666666666
#   98    202 -0.9999999999999432 ... 90.00000000000001 0.16666666666666663
#   99    227  10.666666666666714 ... 90.00000000000001 0.16666666666666663

# %%
# We can also investigate the cumulative of all the runs:
info_table= datasets.info_table(cumulative=True)
info_table
# Out:
# <Table length=500>
#   name  counts       excess       ...   acceptance_off          alpha
#                                   ...
#   str7  int64       float64       ...      float64             float64
# ------- ------ ------------------ ... ------------------ -------------------
# stacked    225 14.666656494140625 ...               90.0  0.1666666716337204
# stacked    458               19.5 ...              180.0  0.1666666716337204
# stacked    654  -3.50006103515625 ...  269.9999694824219  0.1666666865348816
# stacked    881    5.6666259765625 ...              360.0  0.1666666716337204
# stacked   1115     19.16650390625 ... 449.99993896484375  0.1666666865348816
# stacked   1334     17.66650390625 ...  539.9999389648438  0.1666666865348816
# stacked   1555     27.66650390625 ...  629.9999389648438  0.1666666865348816
# stacked   1762     24.83349609375 ...  720.0000610351562  0.1666666567325592
# stacked   1970   18.3331298828125 ...  809.9998779296875  0.1666666865348816
#     ...    ...                ... ...                ...                 ...
# stacked 107539       1183.6171875 ...     44280.05078125 0.16666647791862488
# stacked 107765         1197.78125 ...       44370.046875 0.16666649281978607
# stacked 107998       1216.7890625 ...     44460.05078125 0.16666647791862488
# stacked 108189       1194.2890625 ...     44550.05078125 0.16666647791862488
# stacked 108386         1166.28125 ...       44640.046875 0.16666649281978607
# stacked 108601       1175.6328125 ...      44730.0546875 0.16666646301746368
# stacked 108808           1165.125 ...     44820.05078125 0.16666647791862488
# stacked 109010        1164.109375 ...       44910.046875 0.16666649281978607
# stacked 109237         1174.78125 ...       45000.046875 0.16666649281978607

# %%
# We can plot the excess and the significance
fig, (ax_excess, ax_sqrt_ts) = plt.subplots(figsize=(10, 4), ncols=2, nrows=1)
ax_excess.plot(
    info_table["livetime"].to("h"),
    info_table["excess"],
    marker="o",
    ls="none",
)

ax_excess.set_title("Excess")
ax_excess.set_xlabel("Livetime [h]")
ax_excess.set_ylabel("Excess events")

ax_sqrt_ts.plot(
    info_table["livetime"].to("h"),
    info_table["sqrt_ts"],
    marker="o",
    ls="none",
)

ax_sqrt_ts.set_title("Sqrt(TS)")
ax_sqrt_ts.set_xlabel("Livetime [h]")
ax_sqrt_ts.set_ylabel("Sqrt(TS)")
plt.show()

# %%
dataset_stacked = Datasets(datasets).stack_reduce()

# %%
# let's fit the data with a powerlaw model
spectral_model = PowerLawSpectralModel(index=2.62, amplitude="5e-13 cm-2 s-1 TeV-1", reference="1 TeV")

# make a SkyModel object
model = SkyModel(spectral_model=spectral_model, name="NGC_1068")

# associate the model to the dataset
dataset_stacked.models = model

# set an energy range for the spectral fit
dataset_stacked.mask_fit = dataset_stacked.counts.geom.energy_mask(
    energy_min=0.1 * u.TeV, energy_max=30 * u.TeV
)

# fit the stacked dataset
fit = Fit()
result_stacked = fit.run(dataset_stacked)

print(result_stacked)
print(dataset_stacked.models.parameters.to_table())

# we make a copy here to compare it later
best_fit_model = datasets.models.copy()
# Out:
# OptimizeResult
#
# 	backend    : minuit
# 	method     : migrad
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 66
# 	total stat : 10.36
#
# CovarianceResult
#
# 	backend    : minuit
# 	method     : hesse
# 	success    : True
# 	message    : Hesse terminated successfully.
#
# type    name     value         unit        error   min max frozen link prior
# ---- --------- ---------- -------------- --------- --- --- ------ ---- -----
#          index 2.6564e+00                3.058e-01 nan nan  False
#      amplitude 2.2470e-14 TeV-1 s-1 cm-2 8.708e-15 nan nan  False
#      reference 1.0000e+00            TeV 0.000e+00 nan nan   True

# %%
dataset_stacked.stat_sum()
# Out:
# np.float64(10.355220044149746)

# %%
# I use the energy bins of the dataset. The `downsample` acts reducing the number of bins of a given integer.
#energy_edges = energy_axis.downsample(1).edges 

e_m, e_ma, e_bins = 0.1, 50, 8     #Remember: if you want n bin, you need n+1 
energy_edges = np.logspace(np.log10(e_m), np.log10(e_ma), e_bins) * u.TeV

# let's extract points for the `test_source` model. Errors will be at 1 sigma and upper limits at 3 sigma:
fpe = FluxPointsEstimator(
    energy_edges=energy_edges, source="NGC_1068", selection_optional="all", n_sigma=1, n_sigma_ul=5, n_jobs=7
)
flux_points = fpe.run(datasets=dataset_stacked)

#flux_points.sqrt_ts_threshold_ul = 2

flux_points.to_table()
# Out:
# <Table length=7>
#        e_ref               e_min        ... success        norm_scan
#         TeV                 TeV         ...
#       float64             float64       ...   bool        float64[11]
# ------------------- ------------------- ... ------- ------------------------
# 0.15848931924611137 0.10000000000000002 ...    True 0.2 .. 4.999999999999999
# 0.39810717055349726   0.251188643150958 ...    True 0.2 .. 4.999999999999999
#  1.0000000000000002  0.6309573444801934 ...    True 0.2 .. 4.999999999999999
#   2.511886431509581   1.584893192461114 ...    True 0.2 .. 4.999999999999999
#   6.309573444801934  3.9810717055349736 ...    True 0.2 .. 4.999999999999999
#  15.848931924611144  10.000000000000002 ...    True 0.2 .. 4.999999999999999
#  31.622776601683817  25.118864315095824 ...   False 0.2 .. 4.999999999999999

# %%
# Let's plot them, overlapping the significance
fig, ax = plt.subplots()
sed_type="e2dnde"
flux_points.plot(ax=ax, sed_type=sed_type, color="darkorange")
flux_points.plot_ts_profiles(ax=ax, sed_type=sed_type)
model.spectral_model.plot(ax=ax, energy_bounds=(e_min, e_max), sed_type=sed_type)
model.spectral_model.plot_error(ax=ax, energy_bounds=(e_min, e_max), sed_type=sed_type)
plt.show()

# %%
### We read the created file before 
models_original = Models.read("/Users/tharacaba/Desktop/Tesis_2/MASS_Thesis/simulations/UFO/Experiment/UFO_NGC_1068.yaml")     # lo fitto con una PL

# Let's plot the best-fit model and the spectral points
fig, ax = plt.subplots()
sed_type="e2dnde"
flux_points.plot(ax=ax, sed_type=sed_type, color="red", label="Observed")
model.spectral_model.plot(ax=ax, energy_bounds=(e_min, e_max), sed_type=sed_type, color="green", label="Best-fit")
model.spectral_model.plot_error(ax=ax, energy_bounds=(e_min, e_max), sed_type=sed_type, facecolor="green")
models_original[0].spectral_model.plot(ax=ax, energy_bounds=(e_min, e_max), sed_type=sed_type, color="black", label="Simulated-model")
#model.spectral_model.plot_error(ax=ax, energy_bounds=(2,10)*u.TeV, sed_type=sed_type, facecolor="green")

plt.legend()
#plt.ylim(2e-12,2e-10)
#plt.xlim(0.5,70)
